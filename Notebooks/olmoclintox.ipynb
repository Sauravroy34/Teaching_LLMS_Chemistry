# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    # Get the number of available GPUs
    num_gpus = torch.cuda.device_count()
    print(f"Number of available GPUs: {num_gpus}")

    # Optional: print the name of each GPU
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("CUDA is not available. No GPUs found.")
# Out:
# Number of available GPUs: 2
# GPU 0: Tesla T4
# GPU 1: Tesla T4

# %%
! pip install bitsandbytes
! pip install peft
! pip install --pre deepchem
! pip install ai2-olmo
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.8.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.0rc2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 32.8 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.1
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.17.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft) (26.0rc2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft) (2.8.0+cu126)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft) (4.57.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft) (1.11.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft) (0.6.2)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from peft) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (2025.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (2.32.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (1.2.1rc0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (0.22.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (2026.1.4)
# Collecting deepchem
#   Downloading deepchem-2.8.1.dev20260121224927-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.5.3)
# Collecting numpy<2 (from deepchem)
#   Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from deepchem) (2.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.6.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.13.3)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.15.3)
# Collecting rdkit (from deepchem)
#   Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->deepchem) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->deepchem) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->deepchem) (2025.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit->deepchem) (11.3.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->deepchem) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->deepchem) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.17.0)
# Downloading deepchem-2.8.1.dev20260121224927-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 24.8 MB/s eta 0:00:00a 0:00:01
# Downloading numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 86.6 MB/s eta 0:00:00:00:0100:01
# Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 56.0 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: numpy, rdkit, deepchem
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cesium 0.12.4 requires numpy<3.0,>=2.0, but you have numpy 1.26.4 which is incompatible.
# google-colab 1.0.0 requires google-auth==2.38.0, but you have google-auth 2.47.0 which is incompatible.
# google-colab 1.0.0 requires jupyter-server==2.14.0, but you have jupyter-server 2.12.5 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
# pylibcudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# Successfully installed deepchem-2.8.1.dev20260121224927 numpy-1.26.4 rdkit-2025.9.3
# Collecting ai2-olmo
#   Downloading ai2_olmo-0.6.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (1.26.4)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (2.8.0+cu126)
# Collecting ai2-olmo-core==0.1.0 (from ai2-olmo)
#   Downloading ai2_olmo_core-0.1.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (2.3.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (14.2.0)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (1.42.27)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (2.19.0)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (0.22.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (26.0rc2)
# Collecting cached_path>=1.6.2 (from ai2-olmo)
#   Downloading cached_path-1.8.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (4.57.1)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (6.5.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (0.6.2)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (2.12.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (2.32.5)
# Collecting rich (from ai2-olmo)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: filelock<4.0,>=3.4 in /usr/local/lib/python3.12/dist-packages (from cached_path>=1.6.2->ai2-olmo) (3.20.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from cached_path>=1.6.2->ai2-olmo) (0.36.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.27 in /usr/local/lib/python3.12/dist-packages (from boto3->ai2-olmo) (1.42.27)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3->ai2-olmo) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3->ai2-olmo) (0.16.0)
# Requirement already satisfied: google-auth<3.0dev,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (2.47.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (2.26.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (1.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->ai2-olmo) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->ai2-olmo) (2.19.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (3.4.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->ai2-olmo) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf->ai2-olmo) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->ai2-olmo) (2025.11.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->ai2-olmo) (4.67.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.27->boto3->ai2-olmo) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.43.0,>=1.42.27->boto3->ai2-olmo) (2.6.3)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->ai2-olmo) (1.71.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->ai2-olmo) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->ai2-olmo) (1.26.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->ai2-olmo) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0dev,>=2.26.1->google-cloud-storage->ai2-olmo) (4.9.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (1.2.1rc0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->ai2-olmo) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1->ai2-olmo) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1->ai2-olmo) (3.0.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=2.26.1->google-cloud-storage->ai2-olmo) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.27->boto3->ai2-olmo) (1.17.0)
# Downloading ai2_olmo-0.6.0-py3-none-any.whl (144.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.9/144.9 MB 12.5 MB/s eta 0:00:0000:0100:01
# Downloading ai2_olmo_core-0.1.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 kB 4.4 MB/s eta 0:00:00
# Downloading cached_path-1.8.1-py3-none-any.whl (37 kB)
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.4/242.4 kB 18.2 MB/s eta 0:00:00
# Installing collected packages: rich, cached_path, ai2-olmo-core, ai2-olmo
#   Attempting uninstall: rich
#     Found existing installation: rich 14.2.0
#     Uninstalling rich-14.2.0:
#       Successfully uninstalled rich-14.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# fastai 2.8.4 requires fastcore<1.9,>=1.8.0, but you have fastcore 1.11.3 which is incompatible.
# Successfully installed ai2-olmo-0.6.0 ai2-olmo-core-0.1.0 cached_path-1.8.1 rich-13.9.4

# %%
# %%writefile train.py
import torch
import pytorch_lightning as pl
import deepchem as dc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from peft import (
    LoraConfig,
    get_peft_model,
    prepare_model_for_kbit_training,
    TaskType
)
# Load ClinTox Dataset
from deepchem.molnet import load_clintox
from torch.optim.lr_scheduler import CosineAnnealingLR, LinearLR, SequentialLR
from sklearn.metrics import accuracy_score, roc_auc_score
from torch.nn.functional import softmax
import seaborn as sns
import re

class OlmoDataset(Dataset):
    def __init__(self, mode="Train", max_length=350):
        self.tokenizer = AutoTokenizer.from_pretrained(
            "allenai/OLMo-7B-hf",
            trust_remote_code=True,
            padding_side="right"
        )
        self.tokenizer.pad_token = self.tokenizer.eos_token

        tasks, datasets, transformers = load_clintox(featurizer="raw", splitter='scaffold')
        train, valid, test = datasets
        
        self.task_names = tasks
        
        self.mode = mode.lower()
        if self.mode == "train":
            self.data = train
        elif self.mode == "test":
            self.data = test
        
        self.max_length = max_length
        self.samples = []
        self._filldataset()

    def _filldataset(self):
        for i in range(len(self.data)):
            smiles = self.data.ids[i]
            labels = self.data.y[i]   
            weights = self.data.w[i]

            # Iterate over both tasks (FDA_APPROVED and CT_TOX)
            for task_idx, label in enumerate(labels):
                # Filter valid labels (weight > 0)
                if weights[task_idx] > 0:
                    raw_task_name = self.task_names[task_idx]
                    
                    # Convert raw task name to natural language for the prompt
                    if raw_task_name == "FDA_APPROVED":
                        question_part = "FDA approved"
                    elif raw_task_name == "CT_TOX":
                        question_part = "clinically toxic"
                    else:
                        question_part = raw_task_name

                    self.samples.append(self._create_prompt(smiles, question_part, label))
            
        print(f"[{self.mode.upper()}] Number of samples: {len(self.samples)}")

    def _create_prompt(self, smiles, question_part, label):
        eos_token = self.tokenizer.eos_token
        answer = "Yes" if label == 1.0 else "No"

        full_prompt = (
            "### Instruction:\n"
            f"Is the following molecule {question_part}?\n"
            f"{smiles}\n\n"
            "### Response:\n"
            f"{answer}{eos_token}"
        )
        return full_prompt

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        text = self.samples[idx]
        encodings = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_length,
            return_tensors="pt"
        )
        input_ids = encodings["input_ids"].squeeze(0)
        attention_mask = encodings["attention_mask"].squeeze(0)
        labels = input_ids.clone()

        separator = "### Response:\n"
        parts = text.split(separator)

        if len(parts) >= 2:
            prompt_text = parts[0] + separator
            prompt_encodings = self.tokenizer(
                prompt_text,
                truncation=True,
                max_length=self.max_length,
                return_tensors="pt"
            )
            prompt_len = prompt_encodings["input_ids"].shape[1]

            if prompt_len < len(labels):
                labels[:prompt_len] = -100
        labels[labels == self.tokenizer.pad_token_id] = -100
        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels,
        }

class OLMO_QLoRA(pl.LightningModule):
    def __init__(self):
        super().__init__()

        self.tokenizer = AutoTokenizer.from_pretrained(
            "allenai/OLMo-7B-hf",
            trust_remote_code=True,
            padding_side="right"
        )
        self.tokenizer.pad_token = self.tokenizer.eos_token

        self.bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_use_double_quant=True,
            bnb_4bit_compute_dtype=torch.float16
        )

        self.peft_config = LoraConfig(
            r=32,
            lora_alpha=64,
            target_modules=["q_proj","k_proj","v_proj","o_proj","gate_proj","up_proj","down_proj"],
            lora_dropout=0.05,
            bias="none",
            task_type=TaskType.CAUSAL_LM 
        )
        
    def configure_model(self):
        self.model = AutoModelForCausalLM.from_pretrained(
            "allenai/OLMo-7B-hf",
            quantization_config=self.bnb_config,
            trust_remote_code=True,
        )
        self.model = prepare_model_for_kbit_training(self.model)
        self.model = get_peft_model(self.model, self.peft_config)
        self.model.print_trainable_parameters()

    def forward(self, input_ids, attention_mask, labels=None):
        return self.model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels
        )
        
    def training_step(self, batch, batch_idx):
        outputs = self(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            labels=batch["labels"]
        )
        loss = outputs.loss
        self.log("Train_loss", loss, prog_bar=True, on_step=True, on_epoch=True, logger=True)
        return loss

    def on_train_end(self):
        if self.trainer.is_global_zero:
            print("\nStarting test set evaluation (ROC-AUC & Accuracy)...")
            
            test_dataset = OlmoDataset(mode="test", max_length=350)
            test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
            
            yes_token_id = self.tokenizer.encode("Yes", add_special_tokens=False)[0]
            no_token_id = self.tokenizer.encode("No", add_special_tokens=False)[0]
            
            self.model.eval()
            
            y_true = []
            y_probs = [] 
            y_pred = []  

            print(f"Evaluating on {len(test_loader)} samples using Logits...")

            with torch.no_grad():
                for i, batch in enumerate(test_loader):
                    batch = {k: v.to(self.device) for k, v in batch.items()}
                    input_ids = batch["input_ids"]
                    labels = batch["labels"]
                    attention_mask = batch["attention_mask"]

                    response_mask = (labels != -100)
                    if response_mask.sum() == 0: continue
                    
                    answer_start_index = response_mask.int().argmax(dim=1).item()
                    
                    if answer_start_index > 0:
                        prompt_ids = input_ids[:, :answer_start_index]
                        prompt_mask = attention_mask[:, :answer_start_index]
                    else:
                        continue 

                    outputs = self.model(input_ids=prompt_ids, attention_mask=prompt_mask)
                    next_token_logits = outputs.logits[:, -1, :]
                    
                    yes_logit = next_token_logits[:, yes_token_id]
                    no_logit = next_token_logits[:, no_token_id]
                    
                    relevant_logits = torch.stack([no_logit, yes_logit], dim=1)
                    probs = softmax(relevant_logits, dim=1)
                    
                    prob_yes = probs[:, 1].item()
                    prediction = 1 if prob_yes > 0.5 else 0
                    
                    truth_id = labels[0][answer_start_index].item()
                    if truth_id == yes_token_id:
                        true_label = 1
                    elif truth_id == no_token_id:
                        true_label = 0
                    else:
                        continue 

                    y_true.append(true_label)
                    y_probs.append(prob_yes)
                    y_pred.append(prediction)

                    if i % 100 == 0:
                        print(f"Sample {i}: True={true_label}, Prob(Yes)={prob_yes:.4f}")

            acc = accuracy_score(y_true, y_pred)
            try:
                roc = roc_auc_score(y_true, y_probs)
            except ValueError:
                # Handle edge case if test set has only 1 class
                roc = 0.0

            print("\n=== Test Set Metrics ===")
            print(f"Accuracy: {acc:.4f}")
            print(f"ROC-AUC:  {roc:.4f}")

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=1e-4, weight_decay=1e-4)

        total_steps = self.trainer.estimated_stepping_batches

        warmup_steps = int(0.15*total_steps)
        scheduler_warmup = LinearLR(
            optimizer,
            start_factor=0.01,
            end_factor=1.0,
            total_iters=warmup_steps,
        )

        scheduler_cosine = CosineAnnealingLR(
            optimizer,
            T_max=total_steps - warmup_steps,
        )

        scheduler = SequentialLR(
            optimizer,
            schedulers=[scheduler_warmup, scheduler_cosine],
            milestones=[warmup_steps]
        )

        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "interval": "step"
            }
        }

if __name__ == "__main__":
    dataset = OlmoDataset(mode="train")

    train_loader = DataLoader(dataset, batch_size=1, shuffle=True)

    trainer = pl.Trainer(
            accelerator="gpu",
            devices=2,
            strategy="ddp",
            max_epochs=3,
            precision="16-mixed",
            accumulate_grad_batches=8,
            enable_checkpointing=False,
            gradient_clip_val=1,
        )

    model = OLMO_QLoRA()

    trainer.fit(model, train_loader)
# Out:
# Overwriting train.py

# %%
! python train.py
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# No normalization for NumAmideBonds. Feature removed!
# No normalization for NumAtomStereoCenters. Feature removed!
# No normalization for NumBridgeheadAtoms. Feature removed!
# No normalization for NumHeterocycles. Feature removed!
# No normalization for NumSpiroAtoms. Feature removed!
# No normalization for NumUnspecifiedAtomStereoCenters. Feature removed!
# No normalization for Phi. Feature removed!
# 2026-01-23 08:28:42.137442: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769156922.298573     389 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769156922.347332     389 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769156922.779179     389 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769156922.779223     389 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769156922.779231     389 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769156922.779238     389 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# WARNING:deepchem.models:Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/usr/local/lib/python3.12/dist-packages/deepchem/models/torch_models/__init__.py)
# WARNING:deepchem.models:Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# WARNING:deepchem.models:Skipped loading some Jax models, missing a dependency. No module named 'haiku'
# [TRAIN] Number of samples: 2368
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# No normalization for NumAmideBonds. Feature removed!
# No normalization for NumAtomStereoCenters. Feature removed!
# No normalization for NumBridgeheadAtoms. Feature removed!
# No normalization for NumHeterocycles. Feature removed!
# No normalization for NumSpiroAtoms. Feature removed!
# No normalization for NumUnspecifiedAtomStereoCenters. Feature removed!
# No normalization for Phi. Feature removed!
# 2026-01-23 08:29:02.196612: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769156942.219871     407 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769156942.226912     407 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769156942.245346     407 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769156942.245388     407 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769156942.245398     407 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769156942.245404     407 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# WARNING:deepchem.models:Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/usr/local/lib/python3.12/dist-packages/deepchem/models/torch_models/__init__.py)
# WARNING:deepchem.models:Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# WARNING:deepchem.models:Skipped loading some Jax models, missing a dependency. No module named 'haiku'
# [TRAIN] Number of samples: 2368
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# Loading checkpoint shards: 100%|██████████████████| 6/6 [02:34<00:00, 25.80s/it]
# Loading checkpoint shards: 100%|██████████████████| 6/6 [02:34<00:00, 25.80s/it]
# trainable params: 79,953,920 || all params: 6,968,049,664 || trainable%: 1.1474
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# trainable params: 79,953,920 || all params: 6,968,049,664 || trainable%: 1.1474
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loading `train_dataloader` to estimate number of stepping batches.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ PeftModelForCausalLM │  3.7 B │ train │     0 │
# └───┴───────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 80.0 M
# Non-trainable params: 3.7 B
# Total params: 3.7 B
# Total estimated model params size (MB): 14.9 K
# Modules in train mode: 2242
# Modules in eval mode: 423
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.py:534: Found 423 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 1/1184 0:00:01 • -:--:-- 0.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 2/1184 0:00:02 • 0:18:39 1.06it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 3/1184 0:00:03 • 0:18:39 1.06it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 4/1184 0:00:04 • 0:18:39 1.05it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 5/1184 0:00:05 • 0:18:40 1.05it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 6/1184 0:00:06 • 0:18:40 1.05it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 7/1184 0:00:07 • 0:18:40 1.05it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 8/1184 0:00:08 • 0:19:26 1.01it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━━ 9/1184 0:00:09 • 0:19:10 1.02it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 10/1184 0:00:10 • 0:19:08 1.02it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 11/1184 0:00:11 • 0:19:07 1.02it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 12/1184 0:00:12 • 0:19:05 1.02it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 13/1184 0:00:13 • 0:19:03 1.02it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 14/1184 0:00:14 • 0:19:01 1.03it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 15/1184 0:00:15 • 0:19:00 1.03it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 16/1184 0:00:16 • 0:19:24 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 17/1184 0:00:17 • 0:19:18 1.01it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 18/1184 0:00:18 • 0:19:17 1.01it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 19/1184 0:00:19 • 0:19:16 1.01it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 20/1184 0:00:20 • 0:19:15 1.01it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 21/1184 0:00:21 • 0:19:14 1.01it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 22/1184 0:00:22 • 0:19:13 1.01it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 23/1184 0:00:23 • 0:19:12 1.01it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 24/1184 0:00:24 • 0:19:19 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 25/1184 0:00:25 • 0:19:16 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 26/1184 0:00:26 • 0:19:15 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 27/1184 0:00:27 • 0:19:15 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 28/1184 0:00:28 • 0:19:15 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 29/1184 0:00:29 • 0:19:15 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 30/1184 0:00:30 • 0:19:14 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 31/1184 0:00:31 • 0:19:16 1.00it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 32/1184 0:00:32 • 0:19:24 0.99it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 33/1184 0:00:33 • 0:19:23 0.99it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 34/1184 0:00:34 • 0:19:25 0.99it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 35/1184 0:00:35 • 0:19:27 0.98it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━━━━━━━━━━━━━━━━ 36/1184 0:00:36 • 0:19:30 0.98it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 37/1184 0:00:38 • 0:19:21 0.99it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 38/1184 0:00:39 • 0:19:26 0.98it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 39/1184 0:00:40 • 0:19:28 0.98it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 40/1184 0:00:41 • 0:19:37 0.97it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 41/1184 0:00:42 • 0:19:36 0.97it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 42/1184 0:00:43 • 0:19:40 0.97it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 43/1184 0:00:44 • 0:19:46 0.96it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 44/1184 0:00:45 • 0:19:35 0.97it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 45/1184 0:00:46 • 0:19:35 0.97it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 46/1184 0:00:47 • 0:19:42 0.96it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 47/1184 0:00:48 • 0:19:44 0.96it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 48/1184 0:00:49 • 0:19:52 0.95it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 49/1184 0:00:50 • 0:19:52 0.95it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 50/1184 0:00:52 • 0:19:55 0.95it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 51/1184 0:00:53 • 0:19:58 0.95it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 52/1184 0:00:54 • 0:19:56 0.95it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 53/1184 0:00:55 • 0:20:01 0.94it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 54/1184 0:00:56 • 0:20:04 0.94it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 55/1184 0:00:57 • 0:20:07 0.94it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 56/1184 0:00:58 • 0:20:18 0.93it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 57/1184 0:00:59 • 0:20:18 0.93it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 58/1184 0:01:01 • 0:20:22 0.92it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 59/1184 0:01:02 • 0:20:20 0.92it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 60/1184 0:01:03 • 0:20:26 0.92it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 61/1184 0:01:04 • 0:20:29 0.91it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 62/1184 0:01:05 • 0:20:33 0.91it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 63/1184 0:01:06 • 0:20:36 0.91it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 64/1184 0:01:07 • 0:20:48 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 65/1184 0:01:09 • 0:20:47 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 66/1184 0:01:10 • 0:20:43 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 67/1184 0:01:11 • 0:20:48 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 68/1184 0:01:12 • 0:20:49 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 69/1184 0:01:13 • 0:20:51 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 70/1184 0:01:14 • 0:20:53 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 71/1184 0:01:15 • 0:20:54 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 72/1184 0:01:17 • 0:21:01 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ╸━━━━━━━━━━━━━━━ 73/1184 0:01:18 • 0:20:58 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 74/1184 0:01:19 • 0:20:53 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 75/1184 0:01:20 • 0:20:55 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 76/1184 0:01:21 • 0:20:55 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 77/1184 0:01:22 • 0:20:53 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 78/1184 0:01:23 • 0:20:52 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 79/1184 0:01:24 • 0:20:51 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 80/1184 0:01:25 • 0:20:54 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 81/1184 0:01:27 • 0:20:52 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 82/1184 0:01:28 • 0:20:45 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 83/1184 0:01:29 • 0:20:46 0.88it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 84/1184 0:01:30 • 0:20:43 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 85/1184 0:01:31 • 0:20:39 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 86/1184 0:01:32 • 0:20:35 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 87/1184 0:01:33 • 0:20:31 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 88/1184 0:01:34 • 0:20:33 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 89/1184 0:01:35 • 0:20:25 0.89it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 90/1184 0:01:36 • 0:20:17 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 91/1184 0:01:38 • 0:20:14 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 92/1184 0:01:39 • 0:20:14 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 93/1184 0:01:40 • 0:20:11 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 94/1184 0:01:41 • 0:20:08 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 95/1184 0:01:42 • 0:20:03 0.91it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 96/1184 0:01:43 • 0:20:05 0.90it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 97/1184 0:01:44 • 0:19:58 0.91it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 98/1184 0:01:45 • 0:19:54 0.91it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 99/1184 0:01:46 • 0:19:46 0.92it/s v_num: 1.000
#                                                                Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 100/1184 0:01:47 •        0.92it/s v_num: 1.000
#                                      0:19:45                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 101/1184 0:01:48 •        0.92it/s v_num: 1.000
#                                      0:19:41                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 102/1184 0:01:49 •        0.92it/s v_num: 1.000
#                                      0:19:39                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 103/1184 0:01:50 •        0.92it/s v_num: 1.000
#                                      0:19:37                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 104/1184 0:01:52 •        0.92it/s v_num: 1.000
#                                      0:19:40                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 105/1184 0:01:53 •        0.92it/s v_num: 1.000
#                                      0:19:34                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 106/1184 0:01:54 •        0.92it/s v_num: 1.000
#                                      0:19:31                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 107/1184 0:01:55 •        0.93it/s v_num: 1.000
#                                      0:19:24                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 108/1184 0:01:56 •        0.93it/s v_num: 1.000
#                                      0:19:22                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 109/1184 0:01:57 •        0.93it/s v_num: 1.000
#                                      0:19:19                   Train_loss_step:
# Epoch 0/2  ━╺━━━━━━━━━━━━━━ 110/1184 0:01:58 •        0.93it/s v_num: 1.000
#                                      0:19:17                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 111/1184 0:01:59 •        0.93it/s v_num: 1.000
#                                      0:19:15                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 112/1184 0:02:00 •        0.93it/s v_num: 1.000
#                                      0:19:19                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 113/1184 0:02:01 •        0.93it/s v_num: 1.000
#                                      0:19:15                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 114/1184 0:02:02 •        0.93it/s v_num: 1.000
#                                      0:19:13                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 115/1184 0:02:03 •        0.93it/s v_num: 1.000
#                                      0:19:06                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 116/1184 0:02:04 •        0.93it/s v_num: 1.000
#                                      0:19:04                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 117/1184 0:02:05 •        0.93it/s v_num: 1.000
#                                      0:19:05                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 118/1184 0:02:06 •        0.93it/s v_num: 1.000
#                                      0:19:03                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 119/1184 0:02:08 •        0.93it/s v_num: 1.000
#                                      0:19:00                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 120/1184 0:02:09 •        0.93it/s v_num: 1.000
#                                      0:19:04                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 121/1184 0:02:10 •        0.93it/s v_num: 1.000
#                                      0:19:00                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 122/1184 0:02:11 •        0.93it/s v_num: 1.000
#                                      0:18:59                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 123/1184 0:02:12 •        0.94it/s v_num: 1.000
#                                      0:18:54                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 124/1184 0:02:13 •        0.94it/s v_num: 1.000
#                                      0:18:53                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 125/1184 0:02:14 •        0.93it/s v_num: 1.000
#                                      0:18:55                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 126/1184 0:02:15 •        0.93it/s v_num: 1.000
#                                      0:18:54                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 127/1184 0:02:16 •        0.93it/s v_num: 1.000
#                                      0:18:54                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 128/1184 0:02:17 •        0.93it/s v_num: 1.000
#                                      0:18:59                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 129/1184 0:02:18 •        0.93it/s v_num: 1.000
#                                      0:18:55                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 130/1184 0:02:19 •        0.93it/s v_num: 1.000
#                                      0:18:54                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 131/1184 0:02:21 •        0.93it/s v_num: 1.000
#                                      0:18:49                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 132/1184 0:02:22 •        0.93it/s v_num: 1.000
#                                      0:18:51                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 133/1184 0:02:23 •        0.93it/s v_num: 1.000
#                                      0:18:52                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 134/1184 0:02:24 •        0.93it/s v_num: 1.000
#                                      0:18:53                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 135/1184 0:02:25 •        0.93it/s v_num: 1.000
#                                      0:18:52                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 136/1184 0:02:26 •        0.92it/s v_num: 1.000
#                                      0:18:58                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 137/1184 0:02:27 •        0.92it/s v_num: 1.000
#                                      0:18:55                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 138/1184 0:02:28 •        0.92it/s v_num: 1.000
#                                      0:18:56                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 139/1184 0:02:29 •        0.92it/s v_num: 1.000
#                                      0:18:51                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 140/1184 0:02:30 •        0.92it/s v_num: 1.000
#                                      0:18:53                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 141/1184 0:02:32 •        0.92it/s v_num: 1.000
#                                      0:18:54                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 142/1184 0:02:33 •        0.92it/s v_num: 1.000
#                                      0:18:54                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 143/1184 0:02:34 •        0.92it/s v_num: 1.000
#                                      0:18:53                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 144/1184 0:02:35 •        0.91it/s v_num: 1.000
#                                      0:18:59                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 145/1184 0:02:36 •        0.91it/s v_num: 1.000
#                                      0:18:57                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 146/1184 0:02:37 •        0.91it/s v_num: 1.000
#                                      0:18:57                   Train_loss_step:
# Epoch 0/2  ━╸━━━━━━━━━━━━━━ 147/1184 0:02:38 •        0.92it/s v_num: 1.000
#                                      0:18:51                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 148/1184 0:02:39 •        0.91it/s v_num: 1.000
#                                      0:18:55                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 149/1184 0:02:40 •        0.91it/s v_num: 1.000
#                                      0:18:55                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 150/1184 0:02:41 •        0.91it/s v_num: 1.000
#                                      0:18:54                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 151/1184 0:02:43 •        0.91it/s v_num: 1.000
#                                      0:18:54                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 152/1184 0:02:44 •        0.91it/s v_num: 1.000
#                                      0:18:59                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 153/1184 0:02:45 •        0.91it/s v_num: 1.000
#                                      0:18:56                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 154/1184 0:02:46 •        0.91it/s v_num: 1.000
#                                      0:18:55                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 155/1184 0:02:47 •        0.91it/s v_num: 1.000
#                                      0:18:49                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 156/1184 0:02:48 •        0.91it/s v_num: 1.000
#                                      0:18:51                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 157/1184 0:02:49 •        0.91it/s v_num: 1.000
#                                      0:18:50                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 158/1184 0:02:50 •        0.91it/s v_num: 1.000
#                                      0:18:49                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 159/1184 0:02:51 •        0.91it/s v_num: 1.000
#                                      0:18:49                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 160/1184 0:02:52 •        0.91it/s v_num: 1.000
#                                      0:18:52                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 161/1184 0:02:54 •        0.91it/s v_num: 1.000
#                                      0:18:48                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 162/1184 0:02:55 •        0.91it/s v_num: 1.000
#                                      0:18:46                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 163/1184 0:02:56 •        0.91it/s v_num: 1.000
#                                      0:18:40                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 164/1184 0:02:57 •        0.91it/s v_num: 1.000
#                                      0:18:42                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 165/1184 0:02:58 •        0.91it/s v_num: 1.000
#                                      0:18:39                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 166/1184 0:02:59 •        0.91it/s v_num: 1.000
#                                      0:18:38                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 167/1184 0:03:00 •        0.91it/s v_num: 1.000
#                                      0:18:37                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 168/1184 0:03:01 •        0.91it/s v_num: 1.000
#                                      0:18:40                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 169/1184 0:03:02 •        0.91it/s v_num: 1.000
#                                      0:18:36                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 170/1184 0:03:03 •        0.91it/s v_num: 1.000
#                                      0:18:34                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 171/1184 0:03:04 •        0.92it/s v_num: 1.000
#                                      0:18:28                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 172/1184 0:03:06 •        0.91it/s v_num: 1.000
#                                      0:18:28                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 173/1184 0:03:07 •        0.91it/s v_num: 1.000
#                                      0:18:27                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 174/1184 0:03:08 •        0.91it/s v_num: 1.000
#                                      0:18:26                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 175/1184 0:03:09 •        0.92it/s v_num: 1.000
#                                      0:18:22                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 176/1184 0:03:10 •        0.91it/s v_num: 1.000
#                                      0:18:26                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 177/1184 0:03:11 •        0.91it/s v_num: 1.000
#                                      0:18:21                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 178/1184 0:03:12 •        0.92it/s v_num: 1.000
#                                      0:18:20                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 179/1184 0:03:13 •        0.92it/s v_num: 1.000
#                                      0:18:14                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 180/1184 0:03:14 •        0.92it/s v_num: 1.000
#                                      0:18:16                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 181/1184 0:03:15 •        0.92it/s v_num: 1.000
#                                      0:18:16                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 182/1184 0:03:16 •        0.92it/s v_num: 1.000
#                                      0:18:15                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 183/1184 0:03:18 •        0.92it/s v_num: 1.000
#                                      0:18:14                   Train_loss_step:
# Epoch 0/2  ━━╺━━━━━━━━━━━━━ 184/1184 0:03:19 •        0.91it/s v_num: 1.000
#                                      0:18:18                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 185/1184 0:03:20 •        0.91it/s v_num: 1.000
#                                      0:18:13                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 186/1184 0:03:21 •        0.92it/s v_num: 1.000
#                                      0:18:11                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 187/1184 0:03:22 •        0.92it/s v_num: 1.000
#                                      0:18:04                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 188/1184 0:03:23 •        0.92it/s v_num: 1.000
#                                      0:18:06                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 189/1184 0:03:24 •        0.92it/s v_num: 1.000
#                                      0:18:05                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 190/1184 0:03:25 •        0.92it/s v_num: 1.000
#                                      0:18:03                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 191/1184 0:03:26 •        0.92it/s v_num: 1.000
#                                      0:18:01                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 192/1184 0:03:27 •        0.91it/s v_num: 1.000
#                                      0:18:05                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 193/1184 0:03:28 •        0.92it/s v_num: 1.000
#                                      0:18:01                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 194/1184 0:03:30 •        0.92it/s v_num: 1.000
#                                      0:18:00                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 195/1184 0:03:31 •        0.92it/s v_num: 1.000
#                                      0:17:54                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 196/1184 0:03:32 •        0.92it/s v_num: 1.000
#                                      0:17:56                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 197/1184 0:03:33 •        0.92it/s v_num: 1.000
#                                      0:17:55                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 198/1184 0:03:34 •        0.92it/s v_num: 1.000
#                                      0:17:54                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 199/1184 0:03:35 •        0.92it/s v_num: 1.000
#                                      0:17:53                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 200/1184 0:03:36 •        0.91it/s v_num: 1.000
#                                      0:17:56                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 201/1184 0:03:37 •        0.92it/s v_num: 1.000
#                                      0:17:52                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 202/1184 0:03:38 •        0.92it/s v_num: 1.000
#                                      0:17:51                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 203/1184 0:03:39 •        0.92it/s v_num: 1.000
#                                      0:17:45                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 204/1184 0:03:40 •        0.92it/s v_num: 1.000
#                                      0:17:47                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 205/1184 0:03:41 •        0.92it/s v_num: 1.000
#                                      0:17:46                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 206/1184 0:03:43 •        0.92it/s v_num: 1.000
#                                      0:17:44                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 207/1184 0:03:44 •        0.92it/s v_num: 1.000
#                                      0:17:43                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 208/1184 0:03:45 •        0.92it/s v_num: 1.000
#                                      0:17:45                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 209/1184 0:03:46 •        0.92it/s v_num: 1.000
#                                      0:17:41                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 210/1184 0:03:47 •        0.92it/s v_num: 1.000
#                                      0:17:39                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 211/1184 0:03:48 •        0.92it/s v_num: 1.000
#                                      0:17:33                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 212/1184 0:03:49 •        0.92it/s v_num: 1.000
#                                      0:17:35                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 213/1184 0:03:50 •        0.92it/s v_num: 1.000
#                                      0:17:34                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 214/1184 0:03:51 •        0.92it/s v_num: 1.000
#                                      0:17:33                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 215/1184 0:03:52 •        0.92it/s v_num: 1.000
#                                      0:17:30                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 216/1184 0:03:53 •        0.92it/s v_num: 1.000
#                                      0:17:34                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 217/1184 0:03:55 •        0.92it/s v_num: 1.000
#                                      0:17:31                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 218/1184 0:03:56 •        0.92it/s v_num: 1.000
#                                      0:17:31                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 219/1184 0:03:57 •        0.92it/s v_num: 1.000
#                                      0:17:25                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 220/1184 0:03:58 •        0.92it/s v_num: 1.000
#                                      0:17:27                   Train_loss_step:
# Epoch 0/2  ━━╸━━━━━━━━━━━━━ 221/1184 0:03:59 •        0.92it/s v_num: 1.000
#                                      0:17:26                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 222/1184 0:04:00 •        0.92it/s v_num: 1.000
#                                      0:17:25                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 223/1184 0:04:01 •        0.92it/s v_num: 1.000
#                                      0:17:23                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 224/1184 0:04:02 •        0.92it/s v_num: 1.000
#                                      0:17:27                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 225/1184 0:04:03 •        0.92it/s v_num: 1.000
#                                      0:17:23                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 226/1184 0:04:04 •        0.92it/s v_num: 1.000
#                                      0:17:22                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 227/1184 0:04:05 •        0.92it/s v_num: 1.000
#                                      0:17:17                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 228/1184 0:04:06 •        0.92it/s v_num: 1.000
#                                      0:17:18                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 229/1184 0:04:08 •        0.92it/s v_num: 1.000
#                                      0:17:17                   Train_loss_step:
# Epoch 0/2  ━━━╺━━━━━━━━━━━━ 230/1184 0:04:09 •        0.92it/s v_num: 1.000
#                                      0:17:16                   Train_loss_step:
# ...
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1150/1184 0:20:50 •       0.92it/s v_num: 1.000
#                                       0:00:37                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1151/1184 0:20:51 •       0.92it/s v_num: 1.000
#                                       0:00:36                  Train_loss_step:
#                                                                0.390
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1152/1184 0:20:52 •       0.92it/s v_num: 1.000
#                                       0:00:35                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1153/1184 0:20:53 •       0.92it/s v_num: 1.000
#                                       0:00:34                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1154/1184 0:20:54 •       0.92it/s v_num: 1.000
#                                       0:00:33                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1155/1184 0:20:55 •       0.93it/s v_num: 1.000
#                                       0:00:32                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1156/1184 0:20:56 •       0.92it/s v_num: 1.000
#                                       0:00:31                  Train_loss_step:
#                                                                0.001
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1157/1184 0:20:58 •       0.92it/s v_num: 1.000
#                                       0:00:30                  Train_loss_step:
#                                                                0.005
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1158/1184 0:20:59 •       0.92it/s v_num: 1.000
#                                       0:00:29                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1159/1184 0:21:00 •       0.92it/s v_num: 1.000
#                                       0:00:28                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1160/1184 0:21:01 •       0.92it/s v_num: 1.000
#                                       0:00:27                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1161/1184 0:21:02 •       0.92it/s v_num: 1.000
#                                       0:00:25                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1162/1184 0:21:03 •       0.92it/s v_num: 1.000
#                                       0:00:24                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1163/1184 0:21:04 •       0.93it/s v_num: 1.000
#                                       0:00:23                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1164/1184 0:21:05 •       0.92it/s v_num: 1.000
#                                       0:00:22                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1165/1184 0:21:06 •       0.92it/s v_num: 1.000
#                                       0:00:21                  Train_loss_step:
#                                                                0.002
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1166/1184 0:21:07 •       0.92it/s v_num: 1.000
#                                       0:00:20                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1167/1184 0:21:08 •       0.92it/s v_num: 1.000
#                                       0:00:19                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1168/1184 0:21:10 •       0.92it/s v_num: 1.000
#                                       0:00:18                  Train_loss_step:
#                                                                0.274
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1169/1184 0:21:11 •       0.92it/s v_num: 1.000
#                                       0:00:17                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1170/1184 0:21:12 •       0.92it/s v_num: 1.000
#                                       0:00:16                  Train_loss_step:
#                                                                0.011
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1171/1184 0:21:13 •       0.92it/s v_num: 1.000
#                                       0:00:15                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1172/1184 0:21:14 •       0.92it/s v_num: 1.000
#                                       0:00:14                  Train_loss_step:
#                                                                0.002
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1173/1184 0:21:15 •       0.92it/s v_num: 1.000
#                                       0:00:12                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1174/1184 0:21:16 •       0.92it/s v_num: 1.000
#                                       0:00:11                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1175/1184 0:21:17 •       0.92it/s v_num: 1.000
#                                       0:00:10                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1176/1184 0:21:18 •       0.92it/s v_num: 1.000
#                                       0:00:09                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1177/1184 0:21:19 •       0.92it/s v_num: 1.000
#                                       0:00:08                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1178/1184 0:21:20 •       0.92it/s v_num: 1.000
#                                       0:00:07                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1179/1184 0:21:21 •       0.92it/s v_num: 1.000
#                                       0:00:06                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1180/1184 0:21:23 •       0.92it/s v_num: 1.000
#                                       0:00:05                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1181/1184 0:21:24 •       0.92it/s v_num: 1.000
#                                       0:00:04                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1182/1184 0:21:25 •       0.92it/s v_num: 1.000
#                                       0:00:03                  Train_loss_step:
#                                                                0.001
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━╸ 1183/1184 0:21:26 •       0.92it/s v_num: 1.000
#                                       0:00:02                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
#                                                                0.115            `Trainer.fit` stopped: `max_epochs=3` reached.
#
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Starting test set evaluation (ROC-AUC & Accuracy)...
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# [TEST] Number of samples: 2963m0.115
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Evaluating on 296 samples using Logits...
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Sample 0: True=1, Prob(Yes)=1.000015
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Sample 100: True=1, Prob(Yes)=1.0000
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Sample 200: True=1, Prob(Yes)=0.0250
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
#                            0.115
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# === Test Set Metrics ===   0.115
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Accuracy: 0.9899           0.115
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# ROC-AUC:  0.9984           0.115
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
# Epoch 2/2  ━━━━━━━━━━━━━━━━ 1184/1184 0:21:27 •       0.92it/s v_num: 1.000
#                                       0:00:00                  Train_loss_step:
#                                                                0.000
#                                                                Train_loss_epoch:
#                                                                0.050
