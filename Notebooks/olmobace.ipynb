# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    # Get the number of available GPUs
    num_gpus = torch.cuda.device_count()
    print(f"Number of available GPUs: {num_gpus}")

    # Optional: print the name of each GPU
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("CUDA is not available. No GPUs found.")
# Out:
# Number of available GPUs: 2
# GPU 0: Tesla T4
# GPU 1: Tesla T4

# %%
! pip install bitsandbytes
! pip install peft
! pip install --pre deepchem
! pip install ai2-olmo
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /home/saurav/.local/lib/python3.12/site-packages (from bitsandbytes) (2.7.0)
# Requirement already satisfied: numpy>=1.17 in /home/saurav/.local/lib/python3.12/site-packages (from bitsandbytes) (2.3.4)
# Requirement already satisfied: packaging>=20.9 in /home/saurav/.local/lib/python3.12/site-packages (from bitsandbytes) (24.2)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (4.14.1)
# Requirement already satisfied: setuptools in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (75.8.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.2)
# Requirement already satisfied: fsspec in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (2025.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/saurav/.local/lib/python3.12/site-packages (from torch<3,>=2.3->bitsandbytes) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/saurav/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Downloading bitsandbytes-0.49.2-py3-none-manylinux_2_24_x86_64.whl (60.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 1.1 MB/s  0:00:54m0:00:0100:02
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# WARNING: Error parsing dependencies of arabic-reshaper: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     fonttools (>=3.0<4.0) ; (python_version < "3") and extra == 'with-fonttools'
#               ~~~~~~^
# Installing collected packages: bitsandbytes
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Successfully installed bitsandbytes-0.49.2
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Collecting peft
#   Downloading peft-0.18.1-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: numpy>=1.17 in /home/saurav/.local/lib/python3.12/site-packages (from peft) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in /home/saurav/.local/lib/python3.12/site-packages (from peft) (24.2)
# Requirement already satisfied: psutil in /home/saurav/.local/lib/python3.12/site-packages (from peft) (7.0.0)
# Requirement already satisfied: pyyaml in /usr/lib/python3/dist-packages (from peft) (6.0.1)
# Requirement already satisfied: torch>=1.13.0 in /home/saurav/.local/lib/python3.12/site-packages (from peft) (2.7.0)
# Requirement already satisfied: transformers in /home/saurav/.local/lib/python3.12/site-packages (from peft) (4.51.3)
# Requirement already satisfied: tqdm in /home/saurav/.local/lib/python3.12/site-packages (from peft) (4.67.1)
# Requirement already satisfied: accelerate>=0.21.0 in /home/saurav/.local/lib/python3.12/site-packages (from peft) (1.6.0)
# Requirement already satisfied: safetensors in /home/saurav/.local/lib/python3.12/site-packages (from peft) (0.5.3)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /home/saurav/.local/lib/python3.12/site-packages (from peft) (0.34.5)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from huggingface_hub>=0.25.0->peft) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/saurav/.local/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (2025.2.0)
# Requirement already satisfied: requests in /home/saurav/.local/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/saurav/.local/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (4.14.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/saurav/.local/lib/python3.12/site-packages (from huggingface_hub>=0.25.0->peft) (1.1.10)
# Requirement already satisfied: setuptools in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (75.8.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=1.13.0->peft) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=1.13.0->peft) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/saurav/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/saurav/.local/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->huggingface_hub>=0.25.0->peft) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/saurav/.local/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/saurav/.local/lib/python3.12/site-packages (from requests->huggingface_hub>=0.25.0->peft) (2025.7.14)
# Requirement already satisfied: regex!=2019.12.17 in /home/saurav/.local/lib/python3.12/site-packages (from transformers->peft) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/saurav/.local/lib/python3.12/site-packages (from transformers->peft) (0.21.1)
# Downloading peft-0.18.1-py3-none-any.whl (556 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.0/557.0 kB 4.7 MB/s  0:00:00
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# WARNING: Error parsing dependencies of arabic-reshaper: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     fonttools (>=3.0<4.0) ; (python_version < "3") and extra == 'with-fonttools'
#               ~~~~~~^
# Installing collected packages: peft
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Successfully installed peft-0.18.1
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Collecting deepchem
#   Downloading deepchem-2.8.1.dev20260220202610-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: joblib in /home/saurav/.local/lib/python3.12/site-packages (from deepchem) (1.4.2)
# Collecting numpy<2 (from deepchem)
#   Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: pandas in /home/saurav/.local/lib/python3.12/site-packages (from deepchem) (2.2.3)
# Requirement already satisfied: scikit-learn in /home/saurav/.local/lib/python3.12/site-packages (from deepchem) (1.6.1)
# Requirement already satisfied: sympy in /home/saurav/.local/lib/python3.12/site-packages (from deepchem) (1.14.0)
# Requirement already satisfied: scipy>=1.10.1 in /home/saurav/.local/lib/python3.12/site-packages (from deepchem) (1.15.2)
# Requirement already satisfied: rdkit in /home/saurav/.local/lib/python3.12/site-packages (from deepchem) (2025.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/saurav/.local/lib/python3.12/site-packages (from pandas->deepchem) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/lib/python3/dist-packages (from pandas->deepchem) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/saurav/.local/lib/python3.12/site-packages (from pandas->deepchem) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/saurav/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.17.0)
# Requirement already satisfied: Pillow in /home/saurav/.local/lib/python3.12/site-packages (from rdkit->deepchem) (11.2.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/saurav/.local/lib/python3.12/site-packages (from scikit-learn->deepchem) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/saurav/.local/lib/python3.12/site-packages (from sympy->deepchem) (1.3.0)
# Downloading deepchem-2.8.1.dev20260220202610-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 3.5 MB/s  0:00:00m eta 0:00:01
# Using cached numpy-1.26.4-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.0 MB)
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# WARNING: Error parsing dependencies of arabic-reshaper: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     fonttools (>=3.0<4.0) ; (python_version < "3") and extra == 'with-fonttools'
#               ~~~~~~^
# Installing collected packages: numpy, deepchem
#   Attempting uninstall: numpy
#     WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
#     Found existing installation: numpy 2.3.4
#     Uninstalling numpy-2.3.4:
#       Successfully uninstalled numpy-2.3.4
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [deepchem]1/2 [deepchem]
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# trdg 1.8.0 requires arabic-reshaper==2.1.3, which is not installed.
# datasets 4.0.0 requires dill<0.3.9,>=0.3.0, but you have dill 0.4.0 which is incompatible.
# datasets 4.0.0 requires multiprocess<0.70.17, but you have multiprocess 0.70.18 which is incompatible.
# floris 4.5.1 requires numpy~=2.0, but you have numpy 1.26.4 which is incompatible.
# Successfully installed deepchem-2.8.1.dev20260220202610 numpy-1.26.4
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Defaulting to user installation because normal site-packages is not writeable
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Collecting ai2-olmo
#   Downloading ai2_olmo-0.6.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: numpy<2 in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo) (1.26.4)
# Requirement already satisfied: torch>=2.1 in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo) (2.7.0)
# Collecting ai2-olmo-core==0.1.0 (from ai2-olmo)
#   Downloading ai2_olmo_core-0.1.0-py3-none-any.whl.metadata (14 kB)
# Collecting omegaconf (from ai2-olmo)
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: rich in /usr/lib/python3/dist-packages (from ai2-olmo) (13.7.1)
# Requirement already satisfied: boto3 in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo) (1.42.6)
# Collecting google-cloud-storage (from ai2-olmo)
#   Downloading google_cloud_storage-3.9.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tokenizers in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo) (0.21.1)
# Requirement already satisfied: packaging in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo) (24.2)
# Collecting cached_path>=1.6.2 (from ai2-olmo)
#   Downloading cached_path-1.8.9-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: transformers in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo) (4.51.3)
# Collecting importlib_resources (from ai2-olmo)
#   Downloading importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: safetensors in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (0.5.3)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (2.11.9)
# Requirement already satisfied: requests in /home/saurav/.local/lib/python3.12/site-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (2.32.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/saurav/.local/lib/python3.12/site-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /home/saurav/.local/lib/python3.12/site-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in /home/saurav/.local/lib/python3.12/site-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (4.14.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /home/saurav/.local/lib/python3.12/site-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (0.4.1)
# Requirement already satisfied: filelock<4.0,>=3.4 in /usr/lib/python3/dist-packages (from cached_path>=1.6.2->ai2-olmo) (3.13.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.8.1 in /home/saurav/.local/lib/python3.12/site-packages (from cached_path>=1.6.2->ai2-olmo) (0.34.5)
# Requirement already satisfied: botocore<1.43.0,>=1.42.6 in /home/saurav/.local/lib/python3.12/site-packages (from boto3->ai2-olmo) (1.42.6)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /home/saurav/.local/lib/python3.12/site-packages (from boto3->ai2-olmo) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /home/saurav/.local/lib/python3.12/site-packages (from boto3->ai2-olmo) (0.16.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/saurav/.local/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.6->boto3->ai2-olmo) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /home/saurav/.local/lib/python3.12/site-packages (from botocore<1.43.0,>=1.42.6->boto3->ai2-olmo) (2.5.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /home/saurav/.local/lib/python3.12/site-packages (from google-cloud-storage->ai2-olmo) (2.41.1)
# Collecting google-api-core<3.0.0,>=2.27.0 (from google-cloud-storage->ai2-olmo)
#   Downloading google_api_core-2.30.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-cloud-core<3.0.0,>=2.4.2 (from google-cloud-storage->ai2-olmo)
#   Downloading google_cloud_core-2.5.0-py3-none-any.whl.metadata (3.1 kB)
# Collecting google-resumable-media<3.0.0,>=2.7.2 (from google-cloud-storage->ai2-olmo)
#   Downloading google_resumable_media-2.8.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-crc32c<2.0.0,>=1.1.3 (from google-cloud-storage->ai2-olmo)
#   Downloading google_crc32c-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.3 in /home/saurav/.local/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo) (1.70.0)
# Requirement already satisfied: protobuf<7.0.0,>=4.25.8 in /home/saurav/.local/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /home/saurav/.local/lib/python3.12/site-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo) (1.26.1)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in /usr/lib/python3/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/saurav/.local/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/saurav/.local/lib/python3.12/site-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo) (4.7.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/saurav/.local/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (2025.2.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (6.0.1)
# Requirement already satisfied: tqdm>=4.42.1 in /home/saurav/.local/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (4.67.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/saurav/.local/lib/python3.12/site-packages (from huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (1.1.10)
# Requirement already satisfied: six>=1.5 in /home/saurav/.local/lib/python3.12/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.6->boto3->ai2-olmo) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/saurav/.local/lib/python3.12/site-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /home/saurav/.local/lib/python3.12/site-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (2025.7.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/lib/python3/dist-packages (from rich->ai2-olmo) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/saurav/.local/lib/python3.12/site-packages (from rich->ai2-olmo) (2.19.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /home/saurav/.local/lib/python3.12/site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo) (0.6.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/lib/python3/dist-packages (from markdown-it-py>=2.2.0->rich->ai2-olmo) (0.1.2)
# Requirement already satisfied: setuptools in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (75.8.1)
# Requirement already satisfied: sympy>=1.13.3 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (1.14.0)
# Requirement already satisfied: networkx in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/lib/python3/dist-packages (from torch>=2.1->ai2-olmo) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (1.11.1.6)
# Requirement already satisfied: triton==3.3.0 in /home/saurav/.local/lib/python3.12/site-packages (from torch>=2.1->ai2-olmo) (3.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/saurav/.local/lib/python3.12/site-packages (from sympy>=1.13.3->torch>=2.1->ai2-olmo) (1.3.0)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->ai2-olmo)
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: regex!=2019.12.17 in /home/saurav/.local/lib/python3.12/site-packages (from transformers->ai2-olmo) (2024.11.6)
# Downloading ai2_olmo-0.6.0-py3-none-any.whl (144.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.9/144.9 MB 531.7 kB/s  0:02:25:00:0100:04
# Downloading ai2_olmo_core-0.1.0-py3-none-any.whl (56 kB)
# Downloading cached_path-1.8.9-py3-none-any.whl (37 kB)
# Downloading google_cloud_storage-3.9.0-py3-none-any.whl (321 kB)
# Downloading google_api_core-2.30.0-py3-none-any.whl (173 kB)
# Downloading google_cloud_core-2.5.0-py3-none-any.whl (29 kB)
# Downloading google_crc32c-1.8.0-cp312-cp312-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (33 kB)
# Downloading google_resumable_media-2.8.0-py3-none-any.whl (81 kB)
# Downloading importlib_resources-6.5.2-py3-none-any.whl (37 kB)
# Downloading omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Building wheels for collected packages: antlr4-python3-runtime
#   DEPRECATION: Building 'antlr4-python3-runtime' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'antlr4-python3-runtime'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144590 sha256=50525df7afbfbbb2dd2052a0c23f3b45fbb8f7994fdcd5370193681340de8269
#   Stored in directory: /home/saurav/.cache/pip/wheels/1f/be/48/13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
# Successfully built antlr4-python3-runtime
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# WARNING: Error parsing dependencies of arabic-reshaper: Expected matching RIGHT_PARENTHESIS for LEFT_PARENTHESIS, after version specifier
#     fonttools (>=3.0<4.0) ; (python_version < "3") and extra == 'with-fonttools'
#               ~~~~~~^
# Installing collected packages: antlr4-python3-runtime, omegaconf, importlib_resources, google-crc32c, google-resumable-media, google-api-core, google-cloud-core, google-cloud-storage, cached_path, ai2-olmo-core, ai2-olmo
#   Attempting uninstall: google-api-core0m━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [google-resumable-media]
#    ━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━  4/11 [google-resumable-media]    WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
#     Found existing installation: google-api-core 2.25.2
#     Uninstalling google-api-core-2.25.2:━━━━━━━━━━━━━━━━━━━━━━  4/11 [google-resumable-media]
#       Successfully uninstalled google-api-core-2.25.2━━━━━━━━━  4/11 [google-resumable-media]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11/11 [ai2-olmo]/11 [ai2-olmo]core]torage]
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)
# Successfully installed ai2-olmo-0.6.0 ai2-olmo-core-0.1.0 antlr4-python3-runtime-4.9.3 cached_path-1.8.9 google-api-core-2.30.0 google-cloud-core-2.5.0 google-cloud-storage-3.9.0 google-crc32c-1.8.0 google-resumable-media-2.8.0 importlib_resources-6.5.2 omegaconf-2.3.0
# WARNING: Ignoring invalid distribution ~ebugpy (/home/saurav/.local/lib/python3.12/site-packages)

# %%
# %%writefile train.py
import torch
import pytorch_lightning as pl
import deepchem as dc
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from peft import (
    LoraConfig,
    get_peft_model,
    prepare_model_for_kbit_training,
    TaskType
)
# Changed to BACE Classification
from deepchem.molnet import load_bace_classification
from torch.optim.lr_scheduler import CosineAnnealingLR, LinearLR, SequentialLR
# Changed metrics to Classification metrics
from sklearn.metrics import accuracy_score, roc_auc_score
from torch.nn.functional import softmax
import seaborn as sns
import re

class OlmoDataset(Dataset):
    def __init__(self, mode="Train", max_length=350):
        self.tokenizer = AutoTokenizer.from_pretrained(
            "Codemaster67/ChemOlmo-7b",
            trust_remote_code=True,
            padding_side="right"
        )
        self.tokenizer.pad_token = self.tokenizer.eos_token

        # Load BACE Classification dataset
        # Task: Predict if molecule inhibits BACE1 (Binary: 0 or 1)
        tasks, datasets, transformers = load_bace_classification(featurizer="raw", splitter='scaffold')
        train, valid, test = datasets

        self.mode = mode.lower()
        if self.mode == "train":
            self.data = train
        elif self.mode == "test":
            self.data = test
        
        self.max_length = max_length
        self.samples = []
        self._filldataset()

    def _filldataset(self):
        for i in range(len(self.data)):
            smiles = self.data.ids[i]
            labels = self.data.y[i]   
            weights = self.data.w[i] 

            for task_idx, label in enumerate(labels):
                # Filter out invalid weights (same as your previous request)
                if weights[task_idx] > 0:
                    task_name = "BACE1 inhibitor"
                    self.samples.append(self._create_prompt(smiles, task_name, label))
            
        print(f"[{self.mode.upper()}] Number of samples: {len(self.samples)}")

    def _create_prompt(self, smiles, task_name, label):
        eos_token = self.tokenizer.eos_token
        # Classification format: Yes (1) or No (0)
        answer = "Yes" if label == 1.0 else "No"

        full_prompt = (
            "### Instruction:\n"
            f"Is the following molecule a {task_name}?\n"
            f"{smiles}\n\n"
            "### Response:\n"
            f"{answer}{eos_token}"
        )
        return full_prompt

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        text = self.samples[idx]
        encodings = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_length,
            return_tensors="pt"
        )
        input_ids = encodings["input_ids"].squeeze(0)
        attention_mask = encodings["attention_mask"].squeeze(0)
        labels = input_ids.clone()

        separator = "### Response:\n"
        parts = text.split(separator)

        if len(parts) >= 2:
            prompt_text = parts[0] + separator
            prompt_encodings = self.tokenizer(
                prompt_text,
                truncation=True,
                max_length=self.max_length,
                return_tensors="pt"
            )
            prompt_len = prompt_encodings["input_ids"].shape[1]

            if prompt_len < len(labels):
                labels[:prompt_len] = -100
        labels[labels == self.tokenizer.pad_token_id] = -100
        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": labels,
        }

class OLMO_QLoRA(pl.LightningModule):
    def __init__(self):
        super().__init__()

        self.tokenizer = AutoTokenizer.from_pretrained(
            "Codemaster67/OLMo-7B-USPTO-1k-ZINC",
            trust_remote_code=True,
            padding_side="right"
        )
        self.tokenizer.pad_token = self.tokenizer.eos_token

        self.bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_use_double_quant=True,
            bnb_4bit_compute_dtype=torch.float16
        )

        self.peft_config = LoraConfig(
            r=32,
            lora_alpha=64,
            target_modules=["q_proj","k_proj","v_proj","o_proj","gate_proj","up_proj","down_proj"],
            lora_dropout=0.05,
            bias="none",
            task_type=TaskType.CAUSAL_LM 
        )
        
    def configure_model(self):
        self.model = AutoModelForCausalLM.from_pretrained(
            "Codemaster67/OLMo-7B-USPTO-1k-ZINC",
            quantization_config=self.bnb_config,
            trust_remote_code=True,
        )
        self.model = prepare_model_for_kbit_training(self.model)
        self.model = get_peft_model(self.model, self.peft_config)
        self.model.print_trainable_parameters()

    def forward(self, input_ids, attention_mask, labels=None):
        return self.model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels
        )
        
    def training_step(self, batch, batch_idx):
        outputs = self(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            labels=batch["labels"]
        )
        loss = outputs.loss
        self.log("Train_loss", loss, prog_bar=True, on_step=True, on_epoch=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        outputs = self(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            labels=batch["labels"]
        )
        loss = outputs.loss
        self.log("val_loss", loss, prog_bar=True, sync_dist = True)
        return loss

    def on_train_end(self):
        if self.trainer.is_global_zero:
            print("\nStarting test set evaluation (ROC-AUC & Accuracy)...")
            
            test_dataset = OlmoDataset(mode="test", max_length=350)
            test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)
            
            # Prepare special tokens for classification check
            yes_token_id = self.tokenizer.encode("Yes", add_special_tokens=False)[0]
            no_token_id = self.tokenizer.encode("No", add_special_tokens=False)[0]
            
            self.model.eval()
            
            y_true = []
            y_probs = [] 
            y_pred = []  

            print(f"Evaluating on {len(test_loader)} samples using Logits...")

            with torch.no_grad():
                for i, batch in enumerate(test_loader):
                    batch = {k: v.to(self.device) for k, v in batch.items()}
                    input_ids = batch["input_ids"]
                    labels = batch["labels"]
                    attention_mask = batch["attention_mask"]

                    response_mask = (labels != -100)
                    if response_mask.sum() == 0: continue
                    
                    answer_start_index = response_mask.int().argmax(dim=1).item()
                    
                    if answer_start_index > 0:
                        prompt_ids = input_ids[:, :answer_start_index]
                        prompt_mask = attention_mask[:, :answer_start_index]
                    else:
                        continue 

                    outputs = self.model(input_ids=prompt_ids, attention_mask=prompt_mask)
                    next_token_logits = outputs.logits[:, -1, :]
                    
                    # Extract logits for "Yes" and "No"
                    yes_logit = next_token_logits[:, yes_token_id]
                    no_logit = next_token_logits[:, no_token_id]
                    
                    relevant_logits = torch.stack([no_logit, yes_logit], dim=1)
                    probs = softmax(relevant_logits, dim=1)
                    
                    # Probability of class 1 ("Yes")
                    prob_yes = probs[:, 1].item()
                    prediction = 1 if prob_yes > 0.5 else 0
                    
                    # Get True Label from the encoded labels
                    truth_id = labels[0][answer_start_index].item()
                    if truth_id == yes_token_id:
                        true_label = 1
                    elif truth_id == no_token_id:
                        true_label = 0
                    else:
                        continue 

                    y_true.append(true_label)
                    y_probs.append(prob_yes)
                    y_pred.append(prediction)

                    if i % 50 == 0:
                        print(f"Sample {i}: True={true_label}, Prob(Yes)={prob_yes:.4f}")

            acc = accuracy_score(y_true, y_pred)
            try:
                roc = roc_auc_score(y_true, y_probs)
            except ValueError:
                roc = 0.0

            print("\n=== Test Set Metrics ===")
            print(f"Accuracy: {acc:.4f}")
            print(f"ROC-AUC:  {roc:.4f}")

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=1e-4, weight_decay=1e-4)

        total_steps = self.trainer.estimated_stepping_batches

        warmup_steps = int(0.15*total_steps)
        scheduler_warmup = LinearLR(
            optimizer,
            start_factor=0.01,
            end_factor=1.0,
            total_iters=warmup_steps,
        )

        scheduler_cosine = CosineAnnealingLR(
            optimizer,
            T_max=total_steps - warmup_steps,
        )

        scheduler = SequentialLR(
            optimizer,
            schedulers=[scheduler_warmup, scheduler_cosine],
            milestones=[warmup_steps]
        )

        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "interval": "step"
            }
        }

if __name__ == "__main__":
    pl.seed_everything(42, workers=True)

    dataset = OlmoDataset()
    valid_dataset = OlmoDataset(mode="valid")

    train_loader = DataLoader(dataset, batch_size=1, shuffle=True)
    valid_loader = Dataloader(valid_dataset, batch_size=1, shuffle=False)
    
    early_stop_callback = EarlyStopping(
        monitor="val_loss",
        min_delta=0.00,
        patience=3,      
        mode="min",
        verbose=True
    )
    
    trainer = pl.Trainer(
            accelerator="gpu",
            devices=2,
            strategy="ddp",
            max_epochs=2,          
            precision="16-mixed",
            accumulate_grad_batches=8,
            enable_checkpointing=False,
            gradient_clip_val=1,
            callbacks=[early_stop_callback]

        )

    model = OLMO_QLoRA()

    trainer.fit(model, train_loader, valid_loader)
# Out:
# [TEST] Number of samples: 152
# input =>  80
# 79

# %%
# !python train.py
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# No normalization for NumAmideBonds. Feature removed!
# No normalization for NumAtomStereoCenters. Feature removed!
# No normalization for NumBridgeheadAtoms. Feature removed!
# No normalization for NumHeterocycles. Feature removed!
# No normalization for NumSpiroAtoms. Feature removed!
# No normalization for NumUnspecifiedAtomStereoCenters. Feature removed!
# No normalization for Phi. Feature removed!
# 2026-01-27 01:50:54.598129: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769478654.834551     130 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769478654.898371     130 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769478655.527123     130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769478655.527180     130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769478655.527188     130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769478655.527194     130 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# WARNING:deepchem.models:Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/usr/local/lib/python3.12/dist-packages/deepchem/models/torch_models/__init__.py)
# WARNING:deepchem.models:Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# WARNING:deepchem.models:Skipped loading some Jax models, missing a dependency. No module named 'haiku'
# tokenizer_config.json: 5.40kB [00:00, 3.23MB/s]
# tokenizer.json: 3.57MB [00:00, 6.97MB/s]
# special_tokens_map.json: 100%|█████████████████| 293/293 [00:00<00:00, 2.37MB/s]
# [TRAIN] Number of samples: 1210
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# No normalization for NumAmideBonds. Feature removed!
# No normalization for NumAtomStereoCenters. Feature removed!
# No normalization for NumBridgeheadAtoms. Feature removed!
# No normalization for NumHeterocycles. Feature removed!
# No normalization for NumSpiroAtoms. Feature removed!
# No normalization for NumUnspecifiedAtomStereoCenters. Feature removed!
# No normalization for Phi. Feature removed!
# 2026-01-27 01:51:29.674207: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769478689.697541     150 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769478689.705179     150 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769478689.724724     150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769478689.724763     150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769478689.724767     150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769478689.724771     150 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'repr' attribute with value False was provided to the `Field()` function, which has no effect in the context it was used. 'repr' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/pydantic/_internal/_generate_schema.py:2249: UnsupportedFieldAttributeWarning: The 'frozen' attribute with value True was provided to the `Field()` function, which has no effect in the context it was used. 'frozen' is field-specific metadata, and can only be attached to a model field using `Annotated` metadata or by assignment. This may have happened because an `Annotated` type alias using the `type` statement was used, or if the `Field()` function was attached to a single member of a union type.
#   warnings.warn(
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# WARNING:deepchem.models:Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/usr/local/lib/python3.12/dist-packages/deepchem/models/torch_models/__init__.py)
# WARNING:deepchem.models:Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# WARNING:deepchem.models:Skipped loading some Jax models, missing a dependency. No module named 'haiku'
# [TRAIN] Number of samples: 1210
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# config.json: 100%|█████████████████████████████| 628/628 [00:00<00:00, 4.32MB/s]
# model.safetensors.index.json: 18.4kB [00:00, 10.3MB/s]
# Fetching 3 files:   0%|                                   | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|             | 0.00/5.00G [00:00<?, ?B/s]
#
# model-00003-of-00003.safetensors:   0%|             | 0.00/3.83G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|             | 0.00/4.95G [00:00<?, ?B/s]
#
# model-00003-of-00003.safetensors:   0%|  | 177k/3.83G [00:02<12:48:41, 83.0kB/s]
# model-00002-of-00003.safetensors:   0%|    | 636k/4.95G [00:02<4:35:51, 299kB/s]
#
# model-00003-of-00003.safetensors:   1%|    | 21.7M/3.83G [00:02<04:43, 13.4MB/s]
#
# model-00003-of-00003.safetensors:   1%|    | 33.8M/3.83G [00:02<02:55, 21.7MB/s]
#
# model-00003-of-00003.safetensors:   1%|    | 53.4M/3.83G [00:02<02:14, 28.1MB/s]
# model-00001-of-00003.safetensors:   0%| | 8.62k/5.00G [00:03<499:52:02, 2.78kB/s
#
# model-00003-of-00003.safetensors:   2%|    | 61.5M/3.83G [00:03<02:06, 29.7MB/s]
# model-00001-of-00003.safetensors:   0%|  | 3.58M/5.00G [00:03<1:06:20, 1.25MB/s]
# model-00002-of-00003.safetensors:   0%|   | 1.76M/4.95G [00:03<2:45:39, 498kB/s]
# model-00001-of-00003.safetensors:   0%|    | 22.0M/5.00G [00:04<09:10, 9.04MB/s]
#
# model-00003-of-00003.safetensors:   2%|    | 68.1M/3.83G [00:04<03:40, 17.1MB/s]
# model-00001-of-00003.safetensors:   1%|    | 35.4M/5.00G [00:04<05:15, 15.8MB/s]
#
# model-00003-of-00003.safetensors:   2%|    | 72.6M/3.83G [00:04<03:40, 17.0MB/s]
#
# model-00003-of-00003.safetensors:   2%|    | 76.6M/3.83G [00:04<03:24, 18.3MB/s]
# model-00001-of-00003.safetensors:   1%|    | 41.2M/5.00G [00:04<04:59, 16.5MB/s]
#
# model-00003-of-00003.safetensors:   2%|    | 89.2M/3.83G [00:04<02:14, 27.8MB/s]
#
# model-00003-of-00003.safetensors:   3%|    | 96.8M/3.83G [00:04<02:01, 30.8MB/s]
# model-00001-of-00003.safetensors:   1%|    | 45.8M/5.00G [00:04<05:10, 16.0MB/s]
# model-00001-of-00003.safetensors:   1%|    | 49.3M/5.00G [00:04<04:44, 17.4MB/s]
# model-00002-of-00003.safetensors:   1%|    | 71.0M/4.95G [00:05<04:02, 20.1MB/s]
#
# model-00003-of-00003.safetensors:   4%|▏    | 167M/3.83G [00:05<00:41, 88.6MB/s]
# model-00001-of-00003.safetensors:   1%|    | 52.8M/5.00G [00:05<04:57, 16.6MB/s]
# model-00002-of-00003.safetensors:   4%|▏    | 205M/4.95G [00:05<01:23, 57.0MB/s]
#
# model-00003-of-00003.safetensors:   6%|▎    | 236M/3.83G [00:05<00:39, 90.8MB/s]
# model-00001-of-00003.safetensors:   1%|    | 55.6M/5.00G [00:05<08:13, 10.0MB/s]
# model-00002-of-00003.safetensors:  47%|██▎  | 2.35G/4.95G [00:20<00:14, 174MB/s]
#
# model-00003-of-00003.safetensors:  28%|█   | 1.07G/3.83G [00:21<01:30, 30.6MB/s]
# model-00001-of-00003.safetensors:   9%|▍    | 473M/5.00G [00:21<02:51, 26.5MB/s]
# model-00002-of-00003.safetensors:  49%|██▍  | 2.42G/4.95G [00:21<00:19, 130MB/s]
# model-00002-of-00003.safetensors:  50%|██▌  | 2.48G/4.95G [00:22<00:21, 114MB/s]
#
# model-00003-of-00003.safetensors:  31%|█▏  | 1.17G/3.83G [00:22<01:12, 36.6MB/s]
#
# model-00003-of-00003.safetensors:  32%|█▎  | 1.22G/3.83G [00:24<01:14, 35.1MB/s]
# model-00002-of-00003.safetensors:  52%|██  | 2.55G/4.95G [00:24<00:37, 63.8MB/s]
#
# model-00003-of-00003.safetensors:  33%|█▎  | 1.28G/3.83G [00:26<01:14, 34.1MB/s]
# model-00002-of-00003.safetensors:  53%|██  | 2.62G/4.95G [00:26<00:46, 50.1MB/s]
#
# model-00003-of-00003.safetensors:  35%|█▍  | 1.35G/3.83G [00:28<01:13, 33.7MB/s]
# model-00002-of-00003.safetensors:  54%|██▏ | 2.68G/4.95G [00:28<00:52, 43.3MB/s]
# model-00002-of-00003.safetensors:  56%|██▏ | 2.75G/4.95G [00:29<00:47, 46.6MB/s]
#
# model-00003-of-00003.safetensors:  37%|█▍  | 1.42G/3.83G [00:29<01:03, 38.1MB/s]
# model-00002-of-00003.safetensors:  57%|██▎ | 2.82G/4.95G [00:30<00:37, 57.0MB/s]
#
# model-00003-of-00003.safetensors:  39%|█▌  | 1.48G/3.83G [00:30<00:49, 47.8MB/s]
# model-00001-of-00003.safetensors:  10%|▍    | 481M/5.00G [00:30<11:29, 6.56MB/s]
# model-00002-of-00003.safetensors:  58%|██▎ | 2.89G/4.95G [00:30<00:30, 67.9MB/s]
#
# model-00003-of-00003.safetensors:  40%|█▌  | 1.55G/3.83G [00:30<00:39, 58.0MB/s]
# model-00002-of-00003.safetensors:  60%|██▍ | 2.95G/4.95G [00:31<00:25, 77.2MB/s]
#
# model-00003-of-00003.safetensors:  42%|█▋  | 1.62G/3.83G [00:31<00:32, 67.6MB/s]
# model-00001-of-00003.safetensors:  10%|▍    | 487M/5.00G [00:31<11:29, 6.54MB/s]
# model-00002-of-00003.safetensors:  61%|██▍ | 3.02G/4.95G [00:31<00:23, 83.4MB/s]
#
# model-00003-of-00003.safetensors:  44%|█▊  | 1.68G/3.83G [00:32<00:28, 74.3MB/s]
# model-00001-of-00003.safetensors:  10%|▍    | 493M/5.00G [00:32<11:14, 6.68MB/s]
# model-00002-of-00003.safetensors:  62%|██▍ | 3.09G/4.95G [00:32<00:22, 82.1MB/s]
#
# model-00003-of-00003.safetensors:  46%|█▊  | 1.75G/3.83G [00:33<00:28, 73.7MB/s]
# model-00002-of-00003.safetensors:  64%|██▌ | 3.15G/4.95G [00:34<00:26, 67.4MB/s]
# model-00001-of-00003.safetensors:  80%|███▏| 3.99G/5.00G [01:34<00:12, 82.2MB/s]
# model-00001-of-00003.safetensors:  81%|███▏| 4.06G/5.00G [01:35<00:09, 96.8MB/s]
# model-00001-of-00003.safetensors:  83%|████▏| 4.13G/5.00G [01:35<00:07, 113MB/s]
# model-00001-of-00003.safetensors:  85%|████▎| 4.26G/5.00G [01:35<00:04, 184MB/s]
# model-00001-of-00003.safetensors:  87%|████▎| 4.33G/5.00G [01:35<00:03, 203MB/s]
# model-00001-of-00003.safetensors:  89%|████▍| 4.46G/5.00G [01:36<00:02, 238MB/s]
# model-00001-of-00003.safetensors:  91%|████▌| 4.53G/5.00G [01:36<00:01, 260MB/s]
# model-00001-of-00003.safetensors:  92%|████▌| 4.60G/5.00G [01:36<00:01, 261MB/s]
# model-00001-of-00003.safetensors:  93%|████▋| 4.66G/5.00G [01:36<00:01, 306MB/s]
# model-00001-of-00003.safetensors:  95%|████▋| 4.73G/5.00G [01:37<00:01, 266MB/s]
# model-00001-of-00003.safetensors:  96%|████▊| 4.80G/5.00G [01:37<00:00, 282MB/s]
# model-00001-of-00003.safetensors:  97%|████▊| 4.86G/5.00G [01:37<00:00, 265MB/s]
# model-00001-of-00003.safetensors: 100%|████| 5.00G/5.00G [01:38<00:00, 50.9MB/s]
# Fetching 3 files: 100%|███████████████████████████| 3/3 [01:38<00:00, 32.86s/it]
# Fetching 3 files: 100%|███████████████████████████| 3/3 [01:38<00:00, 32.86s/it]
# Loading checkpoint shards: 100%|██████████████████| 3/3 [01:11<00:00, 23.81s/it]
# Loading checkpoint shards: 100%|██████████████████| 3/3 [01:11<00:00, 23.87s/it]
# generation_config.json: 100%|███████████████████| 111/111 [00:00<00:00, 861kB/s]
# trainable params: 79,953,920 || all params: 6,968,049,664 || trainable%: 1.1474
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# trainable params: 79,953,920 || all params: 6,968,049,664 || trainable%: 1.1474
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loading `train_dataloader` to estimate number of stepping batches.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ PeftModelForCausalLM │  3.7 B │ train │     0 │
# └───┴───────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 80.0 M
# Non-trainable params: 3.7 B
# Total params: 3.7 B
# Total estimated model params size (MB): 14.9 K
# Modules in train mode: 2242
# Modules in eval mode: 423
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.py:534: Found 423 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 1/605 0:00:01 • -:--:-- 0.00it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 2/605 0:00:02 • 0:08:45 1.15it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 3/605 0:00:03 • 0:08:44 1.15it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 4/605 0:00:04 • 0:08:43 1.15it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 5/605 0:00:05 • 0:08:43 1.15it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 6/605 0:00:05 • 0:08:42 1.15it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 7/605 0:00:06 • 0:08:42 1.15it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 8/605 0:00:08 • 0:09:42 1.03it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 9/605 0:00:09 • 0:09:28 1.05it/s v_num: 0.000
#                                                               Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 10/605 0:00:10 • 0:09:22 1.06it/s v_num: 0.000
#                                                                Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 11/605 0:00:10 • 0:09:17 1.07it/s v_num: 0.000
#                                                                Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 12/605 0:00:11 • 0:09:13 1.07it/s v_num: 0.000
#                                                                Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 13/605 0:00:12 • 0:09:10 1.08it/s v_num: 0.000
#                                                                Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 14/605 0:00:13 • 0:09:07 1.08it/s v_num: 0.000
#                                                                Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 15/605 0:00:14 • 0:09:04 1.09it/s v_num: 0.000
#                                                                Train_loss_step:
# Epoch 0/1  ━━━━━━━━━━━━━━━━━ 16/605 0:00:15 • 0:09:22 1.05it/s v_num: 0.000
#                                                                Train_loss_step:
# Epoch 0/1  ━