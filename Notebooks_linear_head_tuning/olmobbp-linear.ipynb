# %%
! pip install bitsandbytes
! pip install peft
! pip install --pre deepchem
! pip install ai2-olmo
# Out:
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.12/dist-packages (0.49.2)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.10.0+cu128)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (1.26.4)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch<3,>=2.3->bitsandbytes) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (0.18.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from peft) (26.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from peft) (6.0.3)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from peft) (2.10.0+cu128)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from peft) (5.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from peft) (4.67.3)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from peft) (1.13.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from peft) (0.7.0)
# Requirement already satisfied: huggingface_hub>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from peft) (1.10.1)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (3.25.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub>=0.25.0->peft) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.0->peft) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=1.13.0->peft) (1.5.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->peft) (0.24.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub>=0.25.0->peft) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.3)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.25.0->peft) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.25.0->peft) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.25.0->peft) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub>=0.25.0->peft) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.25.0->peft) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub>=0.25.0->peft) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub>=0.25.0->peft) (0.1.2)
# Requirement already satisfied: deepchem in /usr/local/lib/python3.12/dist-packages (2.8.1.dev20260609045206)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.5.3)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from deepchem) (2.3.3)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.6.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.14.0)
# Requirement already satisfied: scipy>=1.10.1 in /usr/local/lib/python3.12/dist-packages (from deepchem) (1.16.3)
# Requirement already satisfied: rdkit in /usr/local/lib/python3.12/dist-packages (from deepchem) (2026.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->deepchem) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->deepchem) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->deepchem) (2026.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit->deepchem) (11.3.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->deepchem) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy->deepchem) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->deepchem) (1.17.0)
# Requirement already satisfied: ai2-olmo in /usr/local/lib/python3.12/dist-packages (0.6.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (1.26.4)
# Requirement already satisfied: torch>=2.1 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (2.10.0+cu128)
# Requirement already satisfied: ai2-olmo-core==0.1.0 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (0.1.0)
# Requirement already satisfied: omegaconf in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (2.3.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (13.9.4)
# Requirement already satisfied: boto3 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (1.43.14)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (3.10.1)
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (0.22.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (26.2)
# Requirement already satisfied: cached_path>=1.6.2 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (1.8.10)
# Requirement already satisfied: transformers in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (5.0.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from ai2-olmo) (6.5.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (0.7.0)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (2.12.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from ai2-olmo-core==0.1.0->ai2-olmo) (2.32.4)
# Requirement already satisfied: filelock<4.0,>=3.4 in /usr/local/lib/python3.12/dist-packages (from cached_path>=1.6.2->ai2-olmo) (3.25.2)
# Requirement already satisfied: huggingface-hub<2.0,>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from cached_path>=1.6.2->ai2-olmo) (1.10.1)
# Requirement already satisfied: botocore<1.44.0,>=1.43.14 in /usr/local/lib/python3.12/dist-packages (from boto3->ai2-olmo) (1.43.14)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3->ai2-olmo) (1.1.0)
# Requirement already satisfied: s3transfer<0.18.0,>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from boto3->ai2-olmo) (0.17.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.26.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (2.47.0)
# Requirement already satisfied: google-api-core<3.0.0,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (2.30.3)
# Requirement already satisfied: google-cloud-core<3.0.0,>=2.4.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (2.5.1)
# Requirement already satisfied: google-resumable-media<3.0.0,>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (2.8.2)
# Requirement already satisfied: google-crc32c<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage->ai2-olmo) (1.8.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->ai2-olmo) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->ai2-olmo) (2.20.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (2025.3.0)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.1->ai2-olmo) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.1->ai2-olmo) (1.5.4)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from omegaconf->ai2-olmo) (4.9.3)
# Requirement already satisfied: PyYAML>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from omegaconf->ai2-olmo) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers->ai2-olmo) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers->ai2-olmo) (0.24.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers->ai2-olmo) (4.67.3)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.12/dist-packages (from botocore<1.44.0,>=1.43.14->boto3->ai2-olmo) (2.9.0.post0)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.12/dist-packages (from botocore<1.44.0,>=1.43.14->boto3->ai2-olmo) (2.5.0)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.63.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo) (1.74.0)
# Requirement already satisfied: protobuf<8.0.0,>=4.25.8 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo) (5.29.5)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-api-core<3.0.0,>=2.27.0->google-cloud-storage->ai2-olmo) (1.27.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo) (4.9.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (0.24.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->ai2-olmo) (0.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->ai2-olmo-core==0.1.0->ai2-olmo) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->ai2-olmo-core==0.1.0->ai2-olmo) (2026.2.25)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.1->ai2-olmo) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.1->ai2-olmo) (3.0.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.26.1->google-cloud-storage->ai2-olmo) (0.6.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.44.0,>=1.43.14->boto3->ai2-olmo) (1.17.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=0.8.1->cached_path>=1.6.2->ai2-olmo) (0.0.4)

# %% [markdown]
# # Training linear classifier on top of the olmo back bone

# %%
# %%writefile train_linear.py
import torch
import torch.nn as nn
import pytorch_lightning as pl
import deepchem as dc
import numpy as np
import pandas as pd
from torch.utils.data import Dataset, DataLoader
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM, # Using the base backbone
    BitsAndBytesConfig
)
from peft import (
    LoraConfig,
    get_peft_model,
    prepare_model_for_kbit_training,
    TaskType
)
from rdkit import Chem  
from deepchem.molnet import load_bbbp
from torch.optim.lr_scheduler import CosineAnnealingLR, LinearLR, SequentialLR
from pytorch_lightning.callbacks import EarlyStopping
from sklearn.metrics import accuracy_score, roc_auc_score
from torch.nn.functional import softmax
from rdkit import Chem
import numpy as np

class OlmoDataset(Dataset):
    def __init__(self, mode="Train", max_length=128,do_random = False,prob = 0.2): 
        self.mode = mode.lower()

        self.tokenizer = AutoTokenizer.from_pretrained(
            "harindhar10/Olmo-7b_1M_Smiles_lora",
            trust_remote_code=True,
        )
        self.tokenizer.padding_side = "right"         
        self.tokenizer.pad_token = self.tokenizer.eos_token


        self.do_random = do_random
        self.prob = prob
        
        tasks, datasets, transformers = load_bbbp(featurizer="raw", splitter='scaffold')
        train, valid, test = datasets

        if self.mode == "train":
            self.data = train
        elif self.mode == "valid":
            self.data = valid
        elif self.mode == "test":
            self.data = test
        else:
            self.data = train

        self.max_length = max_length
        self.samples = []
        self._filldataset()


    def _augment_smiles(self,smiles):
        mol = Chem.MolFromSmiles(smiles)

        if mol is None:
            return None
        rand_smi = Chem.MolToSmiles(mol, doRandom=True)

        del mol # rdkit causes memory buildup 
        return rand_smi

    def _filldataset(self):
        for i in range(len(self.data)):
            smiles = self.data.ids[i]
            labels = self.data.y[i]
            weights = self.data.w[i]

            for task_idx, label in enumerate(labels):
                if weights[task_idx] > 0:
                    self.samples.append((smiles, int(label)))

        print(f"[{self.mode.upper()}] Number of samples: {len(self.samples)}")

    def __len__(self):
        return len(self.samples)
        
    def __getitem__(self, idx):
        smiles, label = self.samples[idx]
        
        # ChemFM Style Encapsulation

        if np.random.rand() < self.prob and self.do_random:
            new_smiles = self._augment_smiles(smiles)
            smiles = new_smiles if new_smiles is not None else smiles
            
        
        text = f"<|start_of_smiles|>{smiles}<|end_of_smiles|>"
        
        encodings = self.tokenizer(
            text,
            truncation=True,
            padding="max_length",
            max_length=self.max_length,
            return_tensors="pt"
        ) 
        
        input_ids = encodings["input_ids"].squeeze(0)
        attention_mask = encodings["attention_mask"].squeeze(0)
        label_tensor = torch.tensor(label, dtype=torch.long)

        return {
            "input_ids": input_ids,
            "attention_mask": attention_mask,
            "labels": label_tensor,
        }

class OLMO_ChemFM_Classifier(pl.LightningModule):
    def __init__(self):
        super().__init__()


        self.tokenizer = AutoTokenizer.from_pretrained(
            "harindhar10/Olmo-7b_1M_Smiles_lora",
            trust_remote_code=True,
            padding_side="right"
        )
        self.tokenizer.pad_token = self.tokenizer.eos_token

        self.bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_use_double_quant=True,
            bnb_4bit_compute_dtype=torch.float16
        )

        self.peft_config = LoraConfig(
            r=32,
            lora_alpha= 64,
            target_modules=["q_proj","k_proj","v_proj","o_proj","gate_proj","up_proj","down_proj"],
            lora_dropout=0.25,
            bias="none",
            task_type=TaskType.CAUSAL_LM,
        )
        self.loss_fn = nn.BCEWithLogitsLoss()



    def configure_model(self):
        self.model = AutoModelForCausalLM.from_pretrained(
                "harindhar10/Olmo-7b_1M_Smiles_lora",
                quantization_config=self.bnb_config,
                trust_remote_code=True,
            )
        self.model.config.pad_token_id = self.tokenizer.pad_token_id
            
        self.model = prepare_model_for_kbit_training(self.model)
        self.model = get_peft_model(self.model, self.peft_config)
        self.model.gradient_checkpointing_enable()
            
        hidden_size = self.model.config.hidden_size    
        self.classifier = nn.Sequential(
                nn.Linear(hidden_size, 1)
            )

    def forward(self, input_ids, attention_mask):
        # Forward pass through the backbone, requesting hidden states
        outputs = self.model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            return_dict=True,
            output_hidden_states=True
        )
        
        # Extract the hidden states from the final layer
        last_hidden_states = outputs.hidden_states[-1]
        
        # Find the index of the last non-padded token for each sequence in the batch
        # corresponding to <|end_of_smiles|> or the last padding token
        sequence_lengths = attention_mask.sum(dim=1) - 1
        batch_size = input_ids.shape[0]
        
        # Extract h_l^n: the hidden state corresponding to the final token
        final_token_hidden = last_hidden_states[torch.arange(batch_size), sequence_lengths]
        
        # Pass h_l^n through the explicit linear layer
        logits = self.classifier(final_token_hidden)
        
        return logits
        
    def training_step(self, batch, batch_idx):
        logits = self(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"]
        )
        loss = self.loss_fn(logits.squeeze(-1), batch["labels"].float())
        self.log("Train_loss", loss, prog_bar=True, on_step=True, on_epoch=True, logger=True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        logits = self(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"]
        )
        loss = self.loss_fn(logits.squeeze(-1), batch["labels"].float())
        self.log("val_loss", loss, prog_bar=True, sync_dist=True)
        return loss

    def on_train_end(self):
        if not self.trainer.is_global_zero:
            return
 
        print("\n[INFO] Running test-set evaluation (ROC-AUC & Accuracy) …")
 
        test_ds     = OlmoDataset(mode="test")
        test_loader = DataLoader(test_ds, batch_size=8, shuffle=False, num_workers=2)
 
        self.model.eval()
        self.classifier.eval()
 
        all_probs  = []
        all_labels = []
 
        with torch.no_grad():
            for batch in test_loader:
                batch  = {k: v.to(self.device) for k, v in batch.items()}
                logits = self(batch["input_ids"], batch["attention_mask"])
                probs  = torch.sigmoid(logits).squeeze(-1).cpu().float().numpy()
                all_probs.extend(probs.tolist())
                all_labels.extend(batch["labels"].cpu().numpy().tolist())
 
        preds = [1 if p > 0.5 else 0 for p in all_probs]
        acc   = accuracy_score(all_labels, preds)
        try:
            roc = roc_auc_score(all_labels, all_probs)
        except ValueError:
            roc = 0.0
 
        print("\n=== Test Set Metrics ===")
        print(f"Accuracy : {acc:.4f}")
        print(f"ROC-AUC  : {roc:.4f}")
        self.final_roc_auc = roc

    def configure_optimizers(self):
        # Ensure the custom classifier parameters are included in the optimizer
        trainable_params = [p for p in self.parameters() if p.requires_grad]
        
        total = sum(p.numel() for p in self.parameters() if p.requires_grad)
        print(f"Trainable params: {total}")
        optimizer = torch.optim.AdamW(trainable_params, lr=1e-5, weight_decay=1e-4)

        total_steps = self.trainer.estimated_stepping_batches
        warmup_steps = int(0.15*total_steps)
        
        scheduler_warmup = LinearLR(
            optimizer,
            start_factor=0.01,
            end_factor=1.0,
            total_iters=warmup_steps,
        )

        scheduler_cosine = CosineAnnealingLR(
            optimizer,
            T_max=total_steps - warmup_steps,
        )

        scheduler = SequentialLR(
            optimizer,
            schedulers=[scheduler_warmup, scheduler_cosine],
            milestones=[warmup_steps]
        )

        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "interval": "step"
            }
        }

if __name__ == "__main__":
    num_runs = 3
    roc_scores = []
    
    for i in range(num_runs):
        print(f"\n======================================")
        print(f"        STARTING RUN {i + 1} OF {num_runs}        ")
        print(f"======================================\n")
        
        pl.seed_everything(42 + i, workers=True)

        train_dataset = OlmoDataset(mode="train",do_random = True,prob = 0.25)
        val_dataset = OlmoDataset(mode="valid")
        
        train_loader = DataLoader(train_dataset, batch_size=4, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=4, shuffle=False)
        
        early_stop_callback = EarlyStopping(
            monitor="val_loss",
            min_delta=0.00,
            patience=3,
            verbose=True,
            mode="min"
        )
        
        trainer = pl.Trainer(
            accelerator="gpu",
            max_epochs=20,
            devices = 2,
            strategy = "ddp",
            precision="16-mixed",
            accumulate_grad_batches=2,
            enable_checkpointing=False,
            enable_progress_bar=False,
            gradient_clip_val=1,
            callbacks=[early_stop_callback]
        )

        model = OLMO_ChemFM_Classifier()

        trainer.fit(model, train_loader, val_loader)
        
        if trainer.is_global_zero:
            roc_scores.append(model.final_roc_auc)

    if torch.distributed.is_initialized():
        rank = torch.distributed.get_rank()
    else:
        rank = 0
        
    if rank == 0 and len(roc_scores) > 0:
        mean_roc = np.mean(roc_scores)
        std_roc = np.std(roc_scores)
        
        print("\n\n######################################")
        print("         FINAL TRAINING SUMMARY       ")
        print("######################################")
        print(f"Number of runs evaluated: {len(roc_scores)}")
        print(f"ROC-AUC Scores: {roc_scores}")
        print(f"Mean ROC-AUC: {mean_roc:.4f}")
        print(f"Std ROC-AUC:  {std_roc:.4f}")
        print("######################################\n")
# Out:
# Overwriting train_linear.py

# %%
! python train_linear.py
# Out:
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# No normalization for NumAmideBonds. Feature removed!
# No normalization for NumAtomStereoCenters. Feature removed!
# No normalization for NumBridgeheadAtoms. Feature removed!
# No normalization for NumHeterocycles. Feature removed!
# No normalization for NumSpiroAtoms. Feature removed!
# No normalization for NumUnspecifiedAtomStereoCenters. Feature removed!
# No normalization for Phi. Feature removed!
# 2026-06-11 08:44:58.342766: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781167498.518751     179 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781167498.571219     179 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781167499.006132     179 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781167499.006196     179 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781167499.006209     179 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781167499.006219     179 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# Skipped loading modules with transformers dependency. No module named 'transformers.models.roberta.tokenization_roberta_fast'
# cannot import name 'Chemberta' from 'deepchem.models.torch_models' (/usr/local/lib/python3.12/dist-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/usr/local/lib/python3.12/dist-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'haiku'
#
# ======================================
#         STARTING RUN 1 OF 3
# ======================================
#
# Seed set to 42
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100%|█████████████████████████████| 685/685 [00:00<00:00, 3.24MB/s]
# tokenizer_config.json: 100%|███████████████████| 480/480 [00:00<00:00, 2.25MB/s]
# tokenizer.json: 3.65MB [00:00, 123MB/s]
# [08:45:17] Explicit valence for atom # 1 N, 4, is greater than permitted
# Failed to featurize datapoint 59, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] Explicit valence for atom # 6 N, 4, is greater than permitted
# Failed to featurize datapoint 61, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] Explicit valence for atom # 6 N, 4, is greater than permitted
# Failed to featurize datapoint 391, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] Explicit valence for atom # 11 N, 4, is greater than permitted
# Failed to featurize datapoint 614, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] Explicit valence for atom # 12 N, 4, is greater than permitted
# Failed to featurize datapoint 642, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# Failed to featurize datapoint 645, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# Failed to featurize datapoint 646, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# Failed to featurize datapoint 647, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# Failed to featurize datapoint 648, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# Failed to featurize datapoint 649, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] Explicit valence for atom # 5 N, 4, is greater than permitted
# Failed to featurize datapoint 685, None. Appending empty array
# Exception message: Python argument types in
#     rdkit.Chem.rdmolfiles.CanonicalRankAtoms(NoneType)
# did not match C++ signature:
#     CanonicalRankAtoms(RDKit::ROMol mol, bool breakTies=True, bool includeChirality=True, bool includeIsotopes=True, bool includeAtomMaps=True, bool includeChiralPresence=False)
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:17] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# Exception message: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (2050,) + inhomogeneous part.
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [08:45:18] WARNING: not removing hydrogen atom without neighbors
# [TRAIN] Number of samples: 1631
# [VALID] Number of samples: 204
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# No normalization for SPS. Feature removed!
# No normalization for AvgIpc. Feature removed!
# No normalization for NumAmideBonds. Feature removed!
# No normalization for NumAtomStereoCenters. Feature removed!
# No normalization for NumBridgeheadAtoms. Feature removed!
# No normalization for NumHeterocycles. Feature removed!
# No normalization for NumSpiroAtoms. Feature removed!
# No normalization for NumUnspecifiedAtomStereoCenters. Feature removed!
# No normalization for Phi. Feature removed!
# 2026-06-11 08:45:34.252246: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781167534.275644     203 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781167534.283100     203 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781167534.302884     203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781167534.302911     203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781167534.302915     203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781167534.302919     203 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# WARNING:tensorflow:From /usr/local/lib/python3.12/dist-packages/tensorflow/python/util/deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead
# wandb: WARNING W&B installed but not logged in.  Run `wandb login` or set the WANDB_API_KEY env variable.
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# Skipped loading modules with transformers dependency. No module named 'transformers.models.roberta.tokenization_roberta_fast'
# cannot import name 'Chemberta' from 'deepchem.models.torch_models' (/usr/local/lib/python3.12/dist-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/usr/local/lib/python3.12/dist-packages/deepchem/models/torch_models/__init__.py)
# Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'lightning'
# Skipped loading some Jax models, missing a dependency. No module named 'haiku'
#
# ======================================
#         STARTING RUN 1 OF 3
# ======================================
#
# [rank: 1] Seed set to 42
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [TRAIN] Number of samples: 1631
# [VALID] Number of samples: 204
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# model.safetensors: 100%|████████████████████| 13.8G/13.8G [01:27<00:00, 157MB/s]
# Loading weights: 100%|█| 226/226 [00:33<00:00,  6.75it/s, Materializing param=mo
# Loading weights: 100%|█| 226/226 [00:33<00:00,  6.74it/s, Materializing param=mo
# generation_config.json: 100%|███████████████████| 110/110 [00:00<00:00, 785kB/s]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Trainable params: 79958017
# Trainable params: 79958017
# Loading `train_dataloader` to estimate number of stepping batches.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name       ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ loss_fn    │ BCEWithLogitsLoss    │      0 │ train │     0 │
# │ 1 │ model      │ PeftModelForCausalLM │  3.7 B │ train │     0 │
# │ 2 │ classifier │ Sequential           │  4.1 K │ train │     0 │
# └───┴────────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 80.0 M
# Non-trainable params: 3.7 B
# Total params: 3.7 B
# Total estimated model params size (MB): 14,933.705
# Modules in train mode: 2245
# Modules in eval mode: 423
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.py:538: Found 423 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: The AccumulateGrad node's stream does not match the stream of the node that produced the incoming gradient. This may incur unnecessary synchronization and break CUDA graph capture if the AccumulateGrad node's stream is the default stream. This mismatch is caused by an AccumulateGrad node created prior to the current iteration being kept alive. This can happen if the autograd graph is still being kept alive by tensors such as the loss, or if you are using DDP, which will stash a reference to the node. To resolve the mismatch, delete all references to the autograd graph or ensure that DDP initialization is performed under the same stream as subsequent forwards. If the mismatch is intentional, you can use torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to suppress this warning. (Triggered internally at /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py:865: UserWarning: The AccumulateGrad node's stream does not match the stream of the node that produced the incoming gradient. This may incur unnecessary synchronization and break CUDA graph capture if the AccumulateGrad node's stream is the default stream. This mismatch is caused by an AccumulateGrad node created prior to the current iteration being kept alive. This can happen if the autograd graph is still being kept alive by tensors such as the loss, or if you are using DDP, which will stash a reference to the node. To resolve the mismatch, delete all references to the autograd graph or ensure that DDP initialization is performed under the same stream as subsequent forwards. If the mismatch is intentional, you can use torch.autograd.graph.set_warn_on_accumulate_grad_stream_mismatch(False) to suppress this warning. (Triggered internally at /pytorch/torch/csrc/autograd/input_buffer.cpp:240.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#
# [09:24:37] WARNING: not removing hydrogen atom without neighbors
# [09:25:27] WARNING: not removing hydrogen atom without neighbors
# [09:26:15] WARNING: not removing hydrogen atom without neighbors
# [09:26:36] WARNING: not removing hydrogen atom without neighbors
# [09:26:51] WARNING: not removing hydrogen atom without neighbors
# [09:27:44] WARNING: not removing hydrogen atom without neighbors
# [09:29:37] WARNING: not removing hydrogen atom without neighbors
# [09:29:37] WARNING: not removing hydrogen atom without neighbors
# [09:29:37] WARNING: not removing hydrogen atom without neighbors
# [09:29:45] WARNING: not removing hydrogen atom without neighbors
# [09:30:04] WARNING: not removing hydrogen atom without neighbors
# [09:30:09] WARNING: not removing hydrogen atom without neighbors
# [09:31:35] WARNING: not removing hydrogen atom without neighbors
# [09:31:49] WARNING: not removing hydrogen atom without neighbors
# [09:32:01] WARNING: not removing hydrogen atom without neighbors
# [09:32:04] WARNING: not removing hydrogen atom without neighbors
# [09:32:14] WARNING: not removing hydrogen atom without neighbors
# [09:32:52] WARNING: not removing hydrogen atom without neighbors
# [09:33:04] WARNING: not removing hydrogen atom without neighbors
# [09:34:12] WARNING: not removing hydrogen atom without neighbors
# [09:34:53] WARNING: not removing hydrogen atom without neighbors
# [09:35:45] WARNING: not removing hydrogen atom without neighbors
# [09:35:45] WARNING: not removing hydrogen atom without neighbors
# [09:35:45] WARNING: not removing hydrogen atom without neighbors
# [09:35:58] WARNING: not removing hydrogen atom without neighbors
# [rank: 0] Monitored metric val_loss did not improve in the last 3 records. Best score: 0.121. Signaling Trainer to stop.
# [rank: 1] Monitored metric val_loss did not improve in the last 3 records. Best score: 0.121. Signaling Trainer to stop.
#
# [INFO] Running test-set evaluation (ROC-AUC & Accuracy) …
# [TEST] Number of samples: 204
#
# ======================================
#         STARTING RUN 2 OF 3
# ======================================
#
# [rank: 1] Seed set to 43
# [TRAIN] Number of samples: 1631
# [VALID] Number of samples: 204
#
# === Test Set Metrics ===
# Accuracy : 0.6912
# ROC-AUC  : 0.7222
#
# ======================================
#         STARTING RUN 2 OF 3
# ======================================
#
# [rank: 0] Seed set to 43
# [TRAIN] Number of samples: 1631
# [VALID] Number of samples: 204
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Loading weights: 100%|█| 226/226 [00:48<00:00,  4.63it/s, Materializing param=mo
# Loading weights: 100%|█| 226/226 [00:48<00:00,  4.62it/s, Materializing param=mo
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Trainable params: 79958017
# Trainable params: 79958017
# Loading `train_dataloader` to estimate number of stepping batches.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name       ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ loss_fn    │ BCEWithLogitsLoss    │      0 │ train │     0 │
# │ 1 │ model      │ PeftModelForCausalLM │  3.7 B │ train │     0 │
# │ 2 │ classifier │ Sequential           │  4.1 K │ train │     0 │
# └───┴────────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 80.0 M
# Non-trainable params: 3.7 B
# Total params: 3.7 B
# Total estimated model params size (MB): 14,933.705
# Modules in train mode: 2245
# Modules in eval mode: 423
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.py:538: Found 423 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# [10:09:57] WARNING: not removing hydrogen atom without neighbors
# [rank: 0] Metric val_loss improved by 0.060 >= min_delta = 0.0. New best score: 0.151
# [rank: 1] Metric val_loss improved by 0.060 >= min_delta = 0.0. New best score: 0.151
# [10:10:35] WARNING: not removing hydrogen atom without neighbors
# [10:10:45] WARNING: not removing hydrogen atom without neighbors
# [10:11:29] WARNING: not removing hydrogen atom without neighbors
# [10:12:29] WARNING: not removing hydrogen atom without neighbors
# [10:12:29] WARNING: not removing hydrogen atom without neighbors
# [10:13:12] WARNING: not removing hydrogen atom without neighbors
# [10:14:00] WARNING: not removing hydrogen atom without neighbors
# [10:15:22] WARNING: not removing hydrogen atom without neighbors
# [10:16:06] WARNING: not removing hydrogen atom without neighbors
# [10:16:49] WARNING: not removing hydrogen atom without neighbors
# [10:17:18] WARNING: not removing hydrogen atom without neighbors
# [10:18:08] WARNING: not removing hydrogen atom without neighbors
# [10:20:06] WARNING: not removing hydrogen atom without neighbors
# [10:20:54] WARNING: not removing hydrogen atom without neighbors
# [10:20:59] WARNING: not removing hydrogen atom without neighbors
# [10:20:59] WARNING: not removing hydrogen atom without neighbors
# [10:20:59] WARNING: not removing hydrogen atom without neighbors
# [10:21:12] WARNING: not removing hydrogen atom without neighbors
# [10:21:12] WARNING: not removing hydrogen atom without neighbors
# [10:21:36] WARNING: not removing hydrogen atom without neighbors
# [10:22:15] WARNING: not removing hydrogen atom without neighbors
# [10:23:05] WARNING: not removing hydrogen atom without neighbors
# [10:23:46] WARNING: not removing hydrogen atom without neighbors
# [10:24:26] WARNING: not removing hydrogen atom without neighbors
# [10:24:26] WARNING: not removing hydrogen atom without neighbors
# [10:26:57] WARNING: not removing hydrogen atom without neighbors
# [10:28:05] WARNING: not removing hydrogen atom without neighbors
# [rank: 0] Monitored metric val_loss did not improve in the last 3 records. Best score: 0.151. Signaling Trainer to stop.
# [rank: 1] Monitored metric val_loss did not improve in the last 3 records. Best score: 0.151. Signaling Trainer to stop.
#
# [INFO] Running test-set evaluation (ROC-AUC & Accuracy) …
# [TEST] Number of samples: 204
#
# ======================================
#         STARTING RUN 3 OF 3
# ======================================
#
# [rank: 1] Seed set to 44
# [TRAIN] Number of samples: 1631
# [VALID] Number of samples: 204
#
# === Test Set Metrics ===
# Accuracy : 0.6912
# ROC-AUC  : 0.7302
#
# ======================================
#         STARTING RUN 3 OF 3
# ======================================
#
# [rank: 0] Seed set to 44
# [TRAIN] Number of samples: 1631
# [VALID] Number of samples: 204
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# Loading weights: 100%|█| 226/226 [00:16<00:00, 13.31it/s, Materializing param=mo
# Loading weights: 100%|█| 226/226 [00:16<00:00, 13.39it/s, Materializing param=mo
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Trainable params: 79958017
# Trainable params: 79958017
# Loading `train_dataloader` to estimate number of stepping batches.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/_pytree.py:21: `isinstance(treespec, LeafSpec)` is deprecated, use `isinstance(treespec, TreeSpec) and treespec.is_leaf()` instead.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name       ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ loss_fn    │ BCEWithLogitsLoss    │      0 │ train │     0 │
# │ 1 │ model      │ PeftModelForCausalLM │  3.7 B │ train │     0 │
# │ 2 │ classifier │ Sequential           │  4.1 K │ train │     0 │
# └───┴────────────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 80.0 M
# Non-trainable params: 3.7 B
# Total params: 3.7 B
# Total estimated model params size (MB): 14,933.705
# Modules in train mode: 2245
# Modules in eval mode: 423
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.
# [10:59:35] WARNING: not removing hydrogen atom without neighbors
# [10:59:35] WARNING: not removing hydrogen atom without neighbors
# [11:00:05] WARNING: not removing hydrogen atom without neighbors
# [11:00:50] WARNING: not removing hydrogen atom without neighbors
# [11:01:33] WARNING: not removing hydrogen atom without neighbors
# [11:01:59] WARNING: not removing hydrogen atom without neighbors
# [11:02:03] WARNING: not removing hydrogen atom without neighbors
# [11:02:13] WARNING: not removing hydrogen atom without neighbors
# [11:02:51] WARNING: not removing hydrogen atom without neighbors
# [11:03:20] WARNING: not removing hydrogen atom without neighbors
# [11:03:51] WARNING: not removing hydrogen atom without neighbors
# [11:04:54] WARNING: not removing hydrogen atom without neighbors
# [11:05:38] WARNING: not removing hydrogen atom without neighbors
# [rank: 1] Metric val_loss improved by 0.051 >= min_delta = 0.0. New best score: 0.096
# [rank: 0] Metric val_loss improved by 0.051 >= min_delta = 0.0. New best score: 0.096
# [11:07:43] WARNING: not removing hydrogen atom without neighbors
# [11:07:50] WARNING: not removing hydrogen atom without neighbors
# [11:08:19] WARNING: not removing hydrogen atom without neighbors
# [11:09:12] WARNING: not removing hydrogen atom without neighbors
# [11:09:12] WARNING: not removing hydrogen atom without neighbors
# [11:09:26] WARNING: not removing hydrogen atom without neighbors
# [11:09:45] WARNING: not removing hydrogen atom without neighbors
# [11:10:09] WARNING: not removing hydrogen atom without neighbors
# [11:12:03] WARNING: not removing hydrogen atom without neighbors
# [11:12:51] WARNING: not removing hydrogen atom without neighbors
# [11:14:26] WARNING: not removing hydrogen atom without neighbors
# [11:15:32] WARNING: not removing hydrogen atom without neighbors
# [11:15:32] WARNING: not removing hydrogen atom without neighbors
# [11:15:32] WARNING: not removing hydrogen atom without neighbors
# [11:17:18] WARNING: not removing hydrogen atom without neighbors
# [11:17:18] WARNING: not removing hydrogen atom without neighbors
# [11:17:25] WARNING: not removing hydrogen atom without neighbors
# [11:18:44] WARNING: not removing hydrogen atom without neighbors
# [11:19:30] WARNING: not removing hydrogen atom without neighbors
# [11:19:59] WARNING: not removing hydrogen atom without neighbors
# [11:20:18] WARNING: not removing hydrogen atom without neighbors
# [11:20:18] WARNING: not removing hydrogen atom without neighbors
# [11:22:28] WARNING: not removing hydrogen atom without neighbors
# [11:23:00] WARNING: not removing hydrogen atom without neighbors
# [11:24:12] WARNING: not removing hydrogen atom without neighbors
# [11:24:12] WARNING: not removing hydrogen atom without neighbors
# [11:24:12] WARNING: not removing hydrogen atom without neighbors
# [rank: 0] Monitored metric val_loss did not improve in the last 3 records. Best score: 0.096. Signaling Trainer to stop.
# [rank: 1] Monitored metric val_loss did not improve in the last 3 records. Best score: 0.096. Signaling Trainer to stop.
#
# [INFO] Running test-set evaluation (ROC-AUC & Accuracy) …
# [TEST] Number of samples: 204
#
# === Test Set Metrics ===
# Accuracy : 0.6520
# ROC-AUC  : 0.7333
#
#
# ######################################
#          FINAL TRAINING SUMMARY
# ######################################
# Number of runs evaluated: 3
# ROC-AUC Scores: [0.7222275749108779, 0.7302244917622122, 0.7333076404277868]
# Mean ROC-AUC: 0.7286
# Std ROC-AUC:  0.0047
# ######################################
