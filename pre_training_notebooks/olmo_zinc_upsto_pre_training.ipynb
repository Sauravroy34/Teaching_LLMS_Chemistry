# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    # Get the number of available GPUs
    num_gpus = torch.cuda.device_count()
    print(f"Number of available GPUs: {num_gpus}")

    # Optional: print the name of each GPU
    for i in range(num_gpus):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("CUDA is not available. No GPUs found.")
# Out:
# Number of available GPUs: 2
# GPU 0: Tesla T4
# GPU 1: Tesla T4

# %%
! pip install bitsandbytes
! pip install datasets==3.6.0
# Out:
# Collecting bitsandbytes
#   Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: torch<3,>=2.3 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.8.0+cu126)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (2.0.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from bitsandbytes) (26.0rc2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch<3,>=2.3->bitsandbytes) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3,>=2.3->bitsandbytes) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3,>=2.3->bitsandbytes) (3.0.3)
# Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 34.5 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.49.1
# Collecting datasets==3.6.0
#   Downloading datasets-3.6.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (3.20.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (22.0.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets==3.6.0)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (2.32.5)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (3.6.0)
# Collecting multiprocess<0.70.17 (from datasets==3.6.0)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (0.36.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (26.0rc2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets==3.6.0) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (3.13.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.24.0->datasets==3.6.0) (1.2.1rc0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets==3.6.0) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets==3.6.0) (2025.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets==3.6.0) (1.22.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==3.6.0) (1.17.0)
# Downloading datasets-3.6.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 9.0 MB/s eta 0:00:00a 0:00:01
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.6 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 15.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.7/146.7 kB 11.9 MB/s eta 0:00:00
# Installing collected packages: fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.10.0
#     Uninstalling fsspec-2025.10.0:
#       Successfully uninstalled fsspec-2025.10.0
#   Attempting uninstall: dill
#     Found existing installation: dill 0.4.0
#     Uninstalling dill-0.4.0:
#       Successfully uninstalled dill-0.4.0
#   Attempting uninstall: multiprocess
#     Found existing installation: multiprocess 0.70.18
#     Uninstalling multiprocess-0.70.18:
#       Successfully uninstalled multiprocess-0.70.18
#   Attempting uninstall: datasets
#     Found existing installation: datasets 4.4.2
#     Uninstalling datasets-4.4.2:
#       Successfully uninstalled datasets-4.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.26.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# cudf-cu12 25.6.0 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# gradio 5.49.1 requires pydantic<2.12,>=2.0, but you have pydantic 2.12.5 which is incompatible.
# bigframes 2.26.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# Successfully installed datasets-3.6.0 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16

# %%
# !git config --global credential.helper store
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# %%writefile train_uspto.py
import torch
import pytorch_lightning as pl
from pytorch_lightning.callbacks import Callback
from transformers import (
    AutoTokenizer,
    AutoModelForCausalLM,
    BitsAndBytesConfig
)
from peft import (
    LoraConfig,
    get_peft_model,
    prepare_model_for_kbit_training,
    PeftModel
)
from datasets import load_dataset
from torch.utils.data import DataLoader
import os
import gc
from torch.optim.lr_scheduler import CosineAnnealingLR, LinearLR, SequentialLR

# ------------------------------------------------------------------------
# CONFIGURATION
# ------------------------------------------------------------------------

MODEL_ID = "Codemaster67/OLMo-7B-ZINC20-10k"

NEW_ADAPTER_NAME = "Codemaster67/OLMo-7B-USPTO-1k-ZINC"


class OLMoQLoRA(pl.LightningModule):
    def __init__(self, model_id, adapter_name):
        super().__init__()
        self.save_hyperparameters()
        self.model_id = model_id
        self.adapter_name = adapter_name

        # OLMo requires trust_remote_code=True
        self.tokenizer = AutoTokenizer.from_pretrained(model_id, trust_remote_code=True)
        if self.tokenizer.pad_token is None:
            self.tokenizer.pad_token = self.tokenizer.eos_token

    def configure_model(self):
        bnb_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.float16,
            bnb_4bit_use_double_quant=True,
        )

        model = AutoModelForCausalLM.from_pretrained(
            self.model_id,
            quantization_config=bnb_config,
            trust_remote_code=True
        )

        model.config.use_cache = False
        model.gradient_checkpointing_enable()
        model = prepare_model_for_kbit_training(model)

        # QLoRA Config
        peft_config = LoraConfig(
            r=64,
            lora_alpha=128,
            target_modules="all-linear",
            lora_dropout=0.05,
            bias="none",
            task_type="CAUSAL_LM"
        )
        self.model = get_peft_model(model, peft_config)

        if self.trainer.is_global_zero:
            self.model.print_trainable_parameters()

    def forward(self, input_ids, attention_mask, labels=None):
        return self.model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            labels=labels
        )

    def training_step(self, batch, batch_idx):
        outputs = self(
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            labels=batch["labels"]
        )
        loss = outputs.loss
        self.log("train_loss", loss, prog_bar=True, on_step=True, sync_dist=True)
        return loss

    def configure_optimizers(self):
        optimizer = torch.optim.AdamW(self.parameters(), lr=1e-4, weight_decay=1e-4)

        total_steps = self.trainer.estimated_stepping_batches

        warmup_steps = int(0.15 * total_steps)
        scheduler_warmup = LinearLR(
            optimizer,
            start_factor=0.001,
            end_factor=1.0,
            total_iters=warmup_steps,
        )

        scheduler_cosine = CosineAnnealingLR(
            optimizer,
            T_max=total_steps - warmup_steps,
        )

        scheduler = SequentialLR(
            optimizer,
            schedulers=[scheduler_warmup, scheduler_cosine],
            milestones=[warmup_steps]
        )

        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "interval": "step"
            }
        }


class USPTODataModule(pl.LightningDataModule):
    def __init__(self, tokenizer, batch_size=4):
        super().__init__()
        self.tokenizer = tokenizer
        self.batch_size = batch_size

    def setup(self, stage=None):
        self.dataset = (
            load_dataset("OpenMol/USPTO_1k_TPL-SFT", split="train", streaming=True, trust_remote_code=True)
            .take(10_000)
        )

    def train_dataloader(self):
        def collate_fn(batch):
            text_samples = []
            for item in batch:

                prompt = (
                    f"Instruction: {item['instruction']}\n"
                    f"Input: {item['input']}\n"
                    f"Output: {item['output']}"
                )
                text_samples.append(prompt)

            encodings = self.tokenizer(
                text_samples,
                truncation=True,
                max_length=512,
                padding="max_length",
                return_tensors="pt"
            )

            labels = encodings["input_ids"].clone()
            labels[labels == self.tokenizer.pad_token_id] = -100

            return {
                "input_ids": encodings["input_ids"],
                "attention_mask": encodings["attention_mask"],
                "labels": labels
            }

        return DataLoader(
            self.dataset,
            batch_size=self.batch_size,
            collate_fn=collate_fn,
        )

if __name__ == "__main__":
    pl_model = OLMoQLoRA(MODEL_ID, NEW_ADAPTER_NAME)

    dm = USPTODataModule(pl_model.tokenizer, batch_size=1)

    trainer = pl.Trainer(
        accelerator="gpu",
        devices=2,
        strategy="ddp",
        precision="16-mixed",
        max_epochs=1,
        accumulate_grad_batches=8,
        log_every_n_steps=10,
        enable_checkpointing=False,
        enable_progress_bar=False,
        gradient_clip_val=0.5
    )

    print(f"Starting Training on USPTO dataset (using base: {MODEL_ID})...")
    trainer.fit(pl_model, datamodule=dm)

    # ---------------------------------------------------------
    # MERGE AND PUSH LOGIC
    # ---------------------------------------------------------
    if trainer.is_global_zero:
        print("Training complete. Saving adapter to temporary local storage...")

        pl_model.model.save_pretrained("./temp_adapter_uspto")
        pl_model.tokenizer.save_pretrained("./temp_adapter_uspto")

        print("Freeing VRAM for merge process...")
        del pl_model
        del trainer
        del dm
        gc.collect()
        torch.cuda.empty_cache()

        print("Loading Base Model in FP16 for merging...")
        # NOTE: We load the ZINC-trained model as the base here
        base_model = AutoModelForCausalLM.from_pretrained(
            MODEL_ID,
            return_dict=True,
            torch_dtype=torch.float16,
            device_map="auto",
            trust_remote_code=True
        )

        print("Loading Adapter and Merging...")
        model_to_merge = PeftModel.from_pretrained(base_model, "./temp_adapter_uspto")
        model_to_merge = model_to_merge.merge_and_unload()

        print(f"Pushing FULL MERGED model to Hub: {NEW_ADAPTER_NAME}")
        model_to_merge.push_to_hub(NEW_ADAPTER_NAME)

        # Push tokenizer as well
        tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, trust_remote_code=True)
        tokenizer.push_to_hub(NEW_ADAPTER_NAME)

        print("Done! Full merged USPTO model pushed.")
# Out:
# Overwriting train_uspto.py

# %%
# !python train_uspto.py
# Out:
# 2026-01-26 18:22:38.303283: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769451758.325272     365 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769451758.331761     365 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769451758.348353     365 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769451758.348379     365 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769451758.348385     365 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769451758.348391     365 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# Starting Training on USPTO dataset (using base: Codemaster67/OLMo-7B-ZINC20-10k)...
# Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/2
# 2026-01-26 18:22:52.261586: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769451772.283843     382 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769451772.290099     382 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769451772.305798     382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769451772.305825     382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769451772.305829     382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1769451772.305832     382 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Starting Training on USPTO dataset (using base: Codemaster67/OLMo-7B-ZINC20-10k)...
# Initializing distributed: GLOBAL_RANK: 1, MEMBER: 2/2
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 2 processes
# ----------------------------------------------------------------------------------------------------
#
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:19<00:00,  6.60s/it]
# trainable params: 159,907,840 || all params: 7,048,003,584 || trainable%: 2.2688
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1]
# Loading checkpoint shards: 100%|██████████████████| 3/3 [00:18<00:00,  6.30s/it]
# LOCAL_RANK: 1 - CUDA_VISIBLE_DEVICES: [0,1]
# Loading `train_dataloader` to estimate number of stepping batches.
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/utilities/model_summary/model_summary.py:242: Precision 16-mixed is not supported by the model summary.  Estimated model size in MB will not be accurate. Using 32 bits instead.
# ┏━━━┳━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━┳━━━━━━━┓
# ┃   ┃ Name  ┃ Type                 ┃ Params ┃ Mode  ┃ FLOPs ┃
# ┡━━━╇━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━╇━━━━━━━┩
# │ 0 │ model │ PeftModelForCausalLM │  3.8 B │ train │     0 │
# └───┴───────┴──────────────────────┴────────┴───────┴───────┘
# Trainable params: 159 M
# Non-trainable params: 3.7 B
# Total params: 3.8 B
# Total estimated model params size (MB): 15.2 K
# Modules in train mode: 2242
# Modules in eval mode: 423
# Total FLOPs: 0
# /usr/local/lib/python3.12/dist-packages/pytorch_lightning/loops/fit_loop.py:534: Found 423 module(s) in eval mode at the start of training. This may lead to unexpected behavior during training. If this is intentional, you can ignore this warning.
# `Trainer.fit` stopped: `max_epochs=1` reached.
# Training complete. Saving adapter to temporary local storage...
# Freeing VRAM for merge process...
# Loading Base Model in FP16 for merging...
# `torch_dtype` is deprecated! Use `dtype` instead!
# Loading checkpoint shards: 100%|██████████████████| 3/3 [01:01<00:00, 20.50s/it]
# Loading Adapter and Merging...
# Pushing FULL MERGED model to Hub: Codemaster67/OLMo-7B-USPTO-1k-ZINC
# Processing Files (0 / 0)      : |                  |  0.00B /  0.00B
# New Data Upload               : |                  |  0.00B /  0.00B
#
#   ...0002-of-00003.safetensors:   0%|              |  524kB / 4.95GB
#
# Processing Files (0 / 1)      :   0%|              |  524kB / 13.8GB,  328kB/s
# New Data Upload               :   1%|              |  524kB / 67.1MB,  328kB/s
#
#   ...0002-of-00003.safetensors:   0%|              |  524kB / 4.95GB
#
#   ...0002-of-00003.safetensors:   0%|              |  524kB / 4.95GB
#
# Processing Files (0 / 1)      :   0%|              | 1.05MB / 13.8GB,  477kB/s
# New Data Upload               :   2%|▏             | 1.05MB / 67.1MB,  477kB/s
#
# Processing Files (0 / 1)      :   0%|              | 1.57MB / 13.8GB,  655kB/s
# New Data Upload               :   1%|▏             | 1.57MB /  134MB,  655kB/s
#
#
#   ...0003-of-00003.safetensors:   1%|              | 24.0MB / 3.83GB
#
#   ...0002-of-00003.safetensors:   0%|              | 4.19MB / 4.95GB
#
#
# Processing Files (0 / 2)      :   0%|              | 28.2MB / 13.8GB, 10.8MB/s
# New Data Upload               :   3%|▍             | 4.19MB /  134MB, 1.61MB/s
#
#
#
#   ...0001-of-00003.safetensors:   0%|              | 15.9MB / 5.00GB
#
#   ...0002-of-00003.safetensors:   0%|              | 7.34MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   1%|▏             | 55.9MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   1%|              | 79.2MB / 13.8GB, 28.3MB/s
# New Data Upload               :   5%|▊             | 7.34MB /  134MB, 2.62MB/s
#
#   ...0002-of-00003.safetensors:   0%|              | 9.44MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   2%|▎             | 80.0MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   1%|              |  121MB / 13.8GB, 40.5MB/s
# New Data Upload               :   5%|▋             | 9.44MB /  201MB, 3.15MB/s
#
#   ...0002-of-00003.safetensors:   0%|              | 13.1MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  112MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   1%|▏             |  157MB / 13.8GB, 49.1MB/s
# New Data Upload               :   7%|▉             | 13.1MB /  201MB, 4.10MB/s
#
#   ...0002-of-00003.safetensors:   0%|              | 17.8MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  122MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   1%|▏             |  172MB / 13.8GB, 50.5MB/s
# New Data Upload               :   9%|█▏            | 17.8MB /  201MB, 5.24MB/s
#
#   ...0002-of-00003.safetensors:   0%|              | 23.6MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  125MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   1%|▏             |  180MB / 13.8GB, 50.1MB/s
# New Data Upload               :  12%|█▋            | 23.6MB /  201MB, 6.55MB/s
#
#   ...0002-of-00003.safetensors:   1%|              | 28.8MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  125MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   1%|▏             |  186MB / 13.8GB, 48.9MB/s
# New Data Upload               :  14%|██            | 28.8MB /  201MB, 7.59MB/s
#
#   ...0002-of-00003.safetensors:   1%|              | 34.1MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  125MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   1%|▏             |  199MB / 13.8GB, 49.7MB/s
# New Data Upload               :  17%|██▎           | 34.1MB /  201MB, 8.52MB/s
#
#   ...0002-of-00003.safetensors:   1%|              | 38.3MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  125MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   2%|▏             |  235MB / 13.8GB, 55.9MB/s
# New Data Upload               :  19%|██▋           | 38.3MB /  201MB, 9.11MB/s
#
#   ...0002-of-00003.safetensors:   1%|▏             | 47.7MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  125MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   2%|▎             |  276MB / 13.8GB, 62.8MB/s
# New Data Upload               :  24%|███▎          | 47.7MB /  201MB, 10.8MB/s
#
#   ...0002-of-00003.safetensors:   1%|▏             | 58.2MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  125MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   2%|▎             |  319MB / 13.8GB, 69.3MB/s
# New Data Upload               :  22%|███           | 58.2MB /  268MB, 12.7MB/s
#
#   ...0002-of-00003.safetensors:   1%|▏             | 69.7MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   3%|▍             |  125MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   3%|▎             |  354MB / 13.8GB, 73.8MB/s
# New Data Upload               :  26%|███▋          | 69.7MB /  268MB, 14.5MB/s
#
#   ...0002-of-00003.safetensors:   2%|▏             | 82.3MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   4%|▌             |  165MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   3%|▍             |  423MB / 13.8GB, 84.6MB/s
# New Data Upload               :  31%|████▎         | 82.3MB /  268MB, 16.5MB/s
#
#   ...0002-of-00003.safetensors:   2%|▎             | 92.3MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   5%|▋             |  189MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   3%|▍             |  473MB / 13.8GB, 91.0MB/s
# New Data Upload               :  34%|████▊         | 92.3MB /  268MB, 17.7MB/s
#
#   ...0002-of-00003.safetensors:   2%|▎             |  107MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   6%|▊             |  213MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   4%|▌             |  536MB / 13.8GB, 99.1MB/s
# New Data Upload               :  32%|████▍         |  107MB /  335MB, 19.8MB/s
#
#   ...0002-of-00003.safetensors:   2%|▎             |  122MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   6%|▊             |  237MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   4%|▌             |  599MB / 13.8GB,  107MB/s
# New Data Upload               :  36%|█████         |  122MB /  335MB, 21.8MB/s
#
#   ...0002-of-00003.safetensors:   3%|▍             |  138MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   7%|▉             |  261MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   5%|▋             |  663MB / 13.8GB,  114MB/s
# New Data Upload               :  41%|█████▊        |  138MB /  335MB, 23.9MB/s
#
#   ...0002-of-00003.safetensors:   3%|▍             |  148MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   7%|█             |  285MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   5%|▋             |  721MB / 13.8GB,  120MB/s
# New Data Upload               :  44%|██████▏       |  148MB /  335MB, 24.7MB/s
#
#   ...0002-of-00003.safetensors:   3%|▍             |  158MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   8%|█▏            |  309MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   6%|▊             |  771MB / 13.8GB,  124MB/s
# New Data Upload               :  39%|█████▍        |  158MB /  402MB, 25.4MB/s
#
#   ...0002-of-00003.safetensors:   3%|▍             |  170MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   9%|█▏            |  333MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   6%|▊             |  831MB / 13.8GB,  130MB/s
# New Data Upload               :  42%|█████▉        |  170MB /  402MB, 26.6MB/s
#
#   ...0002-of-00003.safetensors:   4%|▌             |  186MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:   9%|█▎            |  357MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   6%|▉             |  887MB / 13.8GB,  134MB/s
# New Data Upload               :  46%|██████▍       |  186MB /  402MB, 28.2MB/s
#
#   ...0002-of-00003.safetensors:   4%|▌             |  202MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   7%|▉             |  939MB / 13.8GB,  138MB/s
# New Data Upload               :  50%|███████       |  202MB /  402MB, 29.7MB/s
#
#   ...0002-of-00003.safetensors:   4%|▌             |  215MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   7%|▉             |  968MB / 13.8GB,  138MB/s
# New Data Upload               :  40%|█████▌        |  215MB /  537MB, 30.8MB/s
#
#   ...0002-of-00003.safetensors:   5%|▋             |  231MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   7%|█             | 1.01GB / 13.8GB,  140MB/s
# New Data Upload               :  43%|██████        |  231MB /  537MB, 32.1MB/s
#
#   ...0002-of-00003.safetensors:   5%|▋             |  245MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   7%|█             | 1.03GB / 13.8GB,  139MB/s
# New Data Upload               :  46%|██████▍       |  245MB /  537MB, 33.1MB/s
#
#   ...0002-of-00003.safetensors:   5%|▋             |  262MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   8%|█             | 1.04GB / 13.8GB,  137MB/s
# New Data Upload               :  49%|██████▊       |  262MB /  537MB, 34.5MB/s
#
#   ...0002-of-00003.safetensors:   6%|▊             |  280MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   8%|█             | 1.06GB / 13.8GB,  136MB/s
# New Data Upload               :  46%|██████▌       |  280MB /  604MB, 36.0MB/s
#
#   ...0002-of-00003.safetensors:   6%|▊             |  291MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   8%|█             | 1.07GB / 13.8GB,  134MB/s
# New Data Upload               :  44%|██████        |  292MB /  671MB, 36.5MB/s
#
#   ...0002-of-00003.safetensors:   6%|▊             |  309MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   8%|█             | 1.09GB / 13.8GB,  133MB/s
# New Data Upload               :  47%|██████▌       |  313MB /  671MB, 38.2MB/s
#
#   ...0002-of-00003.safetensors:   7%|▉             |  325MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   8%|█▏            | 1.11GB / 13.8GB,  132MB/s
# New Data Upload               :  49%|██████▉       |  332MB /  671MB, 39.5MB/s
#
#   ...0002-of-00003.safetensors:   7%|▉             |  337MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   8%|█▏            | 1.13GB / 13.8GB,  131MB/s
# New Data Upload               :  51%|███████▏      |  345MB /  671MB, 40.2MB/s
#
#   ...0002-of-00003.safetensors:   7%|▉             |  350MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  369MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   8%|█▏            | 1.14GB / 13.8GB,  130MB/s
# New Data Upload               :  45%|██████▎       |  362MB /  805MB, 41.1MB/s
#
#   ...0002-of-00003.safetensors:   7%|█             |  367MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  373MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   8%|█▏            | 1.17GB / 13.8GB,  130MB/s
# New Data Upload               :  44%|██████▏       |  385MB /  872MB, 42.7MB/s
#
#   ...0002-of-00003.safetensors:   8%|█             |  383MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▎            |  375MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   9%|█▏            | 1.19GB / 13.8GB,  129MB/s
# New Data Upload               :  47%|██████▌       |  406MB /  872MB, 44.1MB/s
#
#   ...0002-of-00003.safetensors:   8%|█▏            |  398MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▍            |  378MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   9%|█▏            | 1.21GB / 13.8GB,  129MB/s
# New Data Upload               :  45%|██████▎       |  427MB /  939MB, 45.4MB/s
#
#   ...0002-of-00003.safetensors:   8%|█▏            |  414MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▍            |  380MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   9%|█▏            | 1.23GB / 13.8GB,  128MB/s
# New Data Upload               :  48%|██████▋       |  448MB /  939MB, 46.7MB/s
#
#   ...0002-of-00003.safetensors:   9%|█▏            |  428MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▍            |  385MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   9%|█▎            | 1.25GB / 13.8GB,  128MB/s
# New Data Upload               :  50%|███████       |  471MB /  939MB, 48.0MB/s
#
#   ...0002-of-00003.safetensors:   9%|█▎            |  444MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▍            |  390MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   9%|█▎            | 1.28GB / 13.8GB,  128MB/s
# New Data Upload               :  53%|███████▍      |  495MB /  939MB, 49.5MB/s
#
#   ...0002-of-00003.safetensors:   9%|█▎            |  459MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▍            |  395MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :   9%|█▎            | 1.30GB / 13.8GB,  127MB/s
# New Data Upload               :  55%|███████▋      |  516MB /  939MB, 50.6MB/s
#
#   ...0002-of-00003.safetensors:   9%|█▎            |  465MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  10%|█▍            |  399MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  10%|█▎            | 1.32GB / 13.8GB,  129MB/s
# New Data Upload               :  57%|███████▉      |  536MB /  939MB, 52.6MB/s
#
#   ...0002-of-00003.safetensors:  10%|█▎            |  475MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  11%|█▍            |  402MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  10%|█▎            | 1.33GB / 13.8GB,  131MB/s
# New Data Upload               :  59%|████████▎     |  554MB /  939MB, 54.3MB/s
#
#   ...0002-of-00003.safetensors:  10%|█▎            |  484MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  11%|█▍            |  407MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  10%|█▍            | 1.35GB / 13.8GB,  133MB/s
# New Data Upload               :  57%|███████▉      |  573MB / 1.01GB, 56.2MB/s
#
#   ...0002-of-00003.safetensors:  10%|█▍            |  492MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  11%|█▌            |  411MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  10%|█▍            | 1.37GB / 13.8GB,  134MB/s
# New Data Upload               :  59%|████████▏     |  590MB / 1.01GB, 57.8MB/s
#
#   ...0002-of-00003.safetensors:  10%|█▍            |  496MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  11%|█▌            |  414MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  10%|█▍            | 1.39GB / 13.8GB,  136MB/s
# New Data Upload               :  60%|████████▍     |  604MB / 1.01GB, 59.2MB/s
#
#   ...0002-of-00003.safetensors:  10%|█▍            |  504MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  11%|█▌            |  418MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  10%|█▍            | 1.41GB / 13.8GB,  138MB/s
# New Data Upload               :  62%|████████▋     |  625MB / 1.01GB, 61.3MB/s
#
#   ...0002-of-00003.safetensors:  10%|█▍            |  508MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  11%|█▌            |  427MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  10%|█▍            | 1.43GB / 13.8GB,  140MB/s
# New Data Upload               :  64%|████████▉     |  646MB / 1.01GB, 63.3MB/s
#
#   ...0002-of-00003.safetensors:  10%|█▍            |  517MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  11%|█▌            |  430MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  11%|█▍            | 1.45GB / 13.8GB,  142MB/s
# New Data Upload               :  66%|█████████▎    |  666MB / 1.01GB, 65.2MB/s
#
#   ...0002-of-00003.safetensors:  11%|█▍            |  526MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  11%|█▌            |  433MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  11%|█▍            | 1.47GB / 13.8GB,  144MB/s
# New Data Upload               :  68%|█████████▌    |  684MB / 1.01GB, 67.0MB/s
#
#   ...0002-of-00003.safetensors:  11%|█▌            |  535MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  12%|█▌            |  441MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  11%|█▌            | 1.49GB / 13.8GB,  146MB/s
# New Data Upload               :  66%|█████████▎    |  710MB / 1.07GB, 69.6MB/s
#
#   ...0002-of-00003.safetensors:  11%|█▌            |  541MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  12%|█▋            |  451MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  11%|█▌            | 1.51GB / 13.8GB,  148MB/s
# New Data Upload               :  64%|████████▉     |  732MB / 1.14GB, 71.6MB/s
#
#   ...0002-of-00003.safetensors:  11%|█▌            |  551MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  12%|█▋            |  455MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  11%|█▌            | 1.53GB / 13.8GB,  150MB/s
# New Data Upload               :  66%|█████████▏    |  752MB / 1.14GB, 73.6MB/s
#
#   ...0002-of-00003.safetensors:  11%|█▌            |  558MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  12%|█▋            |  459MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  11%|█▌            | 1.55GB / 13.8GB,  149MB/s
# New Data Upload               :  64%|████████▉     |  770MB / 1.21GB, 75.1MB/s
#
#   ...0002-of-00003.safetensors:  11%|█▌            |  565MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  12%|█▋            |  462MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  11%|█▌            | 1.57GB / 13.8GB,  146MB/s
# New Data Upload               :  65%|█████████▏    |  788MB / 1.21GB, 76.5MB/s
#
#   ...0002-of-00003.safetensors:  12%|█▋            |  576MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  12%|█▋            |  466MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  12%|█▌            | 1.59GB / 13.8GB,  144MB/s
# New Data Upload               :  67%|█████████▍    |  812MB / 1.21GB, 78.6MB/s
#
#   ...0002-of-00003.safetensors:  12%|█▋            |  585MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  12%|█▋            |  469MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  12%|█▋            | 1.61GB / 13.8GB,  143MB/s
# New Data Upload               :  69%|█████████▋    |  833MB / 1.21GB, 80.4MB/s
#
#   ...0002-of-00003.safetensors:  12%|█▋            |  594MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  12%|█▋            |  477MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  12%|█▋            | 1.64GB / 13.8GB,  144MB/s
# New Data Upload               :  71%|█████████▉    |  860MB / 1.21GB, 82.6MB/s
#
#   ...0002-of-00003.safetensors:  12%|█▋            |  601MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  13%|█▊            |  482MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  12%|█▋            | 1.66GB / 13.8GB,  145MB/s
# New Data Upload               :  69%|█████████▌    |  876MB / 1.27GB, 83.6MB/s
#
#   ...0002-of-00003.safetensors:  12%|█▋            |  609MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  13%|█▊            |  490MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  12%|█▋            | 1.68GB / 13.8GB,  146MB/s
# New Data Upload               :  67%|█████████▎    |  897MB / 1.34GB, 85.1MB/s
#
#   ...0002-of-00003.safetensors:  12%|█▋            |  617MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  13%|█▊            |  500MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  12%|█▋            | 1.70GB / 13.8GB,  147MB/s
# New Data Upload               :  69%|█████████▌    |  919MB / 1.34GB, 86.7MB/s
#
#   ...0002-of-00003.safetensors:  13%|█▊            |  624MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  13%|█▊            |  508MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  13%|█▊            | 1.72GB / 13.8GB,  146MB/s
# New Data Upload               :  70%|█████████▊    |  942MB / 1.34GB, 88.6MB/s
#
#   ...0002-of-00003.safetensors:  13%|█▊            |  630MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  14%|█▉            |  517MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  13%|█▊            | 1.74GB / 13.8GB,  144MB/s
# New Data Upload               :  72%|██████████    |  960MB / 1.34GB, 89.5MB/s
#
#   ...0002-of-00003.safetensors:  13%|█▊            |  638MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  14%|█▉            |  528MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  13%|█▊            | 1.77GB / 13.8GB,  142MB/s
# New Data Upload               :  70%|█████████▊    |  985MB / 1.41GB, 90.9MB/s
#
#   ...0002-of-00003.safetensors:  13%|█▊            |  640MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  14%|█▉            |  533MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  13%|█▊            | 1.78GB / 13.8GB,  140MB/s
# New Data Upload               :  71%|█████████▉    | 1.00GB / 1.41GB, 91.2MB/s
#
#   ...0002-of-00003.safetensors:  13%|█▊            |  649MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  14%|█▉            |  533MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  13%|█▊            | 1.80GB / 13.8GB,  135MB/s
# New Data Upload               :  69%|█████████▋    | 1.02GB / 1.48GB, 91.9MB/s
#
#   ...0002-of-00003.safetensors:  13%|█▊            |  657MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  14%|█▉            |  537MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  13%|█▊            | 1.82GB / 13.8GB,  132MB/s
# New Data Upload               :  70%|█████████▊    | 1.04GB / 1.48GB, 92.8MB/s
#
#   ...0002-of-00003.safetensors:  13%|█▉            |  663MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  14%|█▉            |  543MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  13%|█▊            | 1.84GB / 13.8GB,  128MB/s
# New Data Upload               :  72%|██████████    | 1.06GB / 1.48GB, 93.2MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  668MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  14%|█▉            |  547MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  13%|█▉            | 1.85GB / 13.8GB,  123MB/s
# New Data Upload               :  73%|██████████▏   | 1.07GB / 1.48GB, 93.0MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  674MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  15%|██            |  555MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  14%|█▉            | 1.87GB / 13.8GB,  118MB/s
# New Data Upload               :  74%|██████████▎   | 1.09GB / 1.48GB, 93.2MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  681MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  15%|██            |  561MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  14%|█▉            | 1.89GB / 13.8GB,  115MB/s
# New Data Upload               :  75%|██████████▌   | 1.11GB / 1.48GB, 94.3MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  687MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  15%|██            |  570MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  14%|█▉            | 1.91GB / 13.8GB,  112MB/s
# New Data Upload               :  70%|█████████▊    | 1.13GB / 1.61GB, 95.5MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  690MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  15%|██            |  575MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  14%|█▉            | 1.93GB / 13.8GB,  107MB/s
# New Data Upload               :  71%|█████████▉    | 1.15GB / 1.61GB, 95.7MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  695MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  15%|██▏           |  584MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  14%|█▉            | 1.95GB / 13.8GB,  104MB/s
# New Data Upload               :  73%|██████████▏   | 1.17GB / 1.61GB, 96.3MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  698MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  16%|██▏           |  594MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  14%|█▉            | 1.97GB / 13.8GB,  101MB/s
# New Data Upload               :  74%|██████████▎   | 1.19GB / 1.61GB, 96.6MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  703MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  16%|██▏           |  606MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  14%|██            | 1.99GB / 13.8GB,  100MB/s
# New Data Upload               :  75%|██████████▌   | 1.21GB / 1.61GB, 97.2MB/s
#
#   ...0002-of-00003.safetensors:  14%|█▉            |  705MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  16%|██▏           |  614MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  15%|██            | 2.00GB / 13.8GB, 97.7MB/s
# New Data Upload               :  76%|██████████▋   | 1.22GB / 1.61GB, 97.3MB/s
#
#   ...0002-of-00003.safetensors:  14%|██            |  712MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  16%|██▎           |  619MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  15%|██            | 2.03GB / 13.8GB, 98.1MB/s
# New Data Upload               :  77%|██████████▊   | 1.25GB / 1.61GB, 98.1MB/s
#
#   ...0002-of-00003.safetensors:  14%|██            |  716MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  16%|██▎           |  624MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  15%|██            | 2.05GB / 13.8GB, 98.4MB/s
# New Data Upload               :  75%|██████████▌   | 1.27GB / 1.68GB, 98.4MB/s
#
#   ...0002-of-00003.safetensors:  15%|██            |  725MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  16%|██▎           |  628MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  15%|██            | 2.07GB / 13.8GB, 98.9MB/s
# New Data Upload               :  74%|██████████▎   | 1.29GB / 1.74GB, 98.9MB/s
#
#   ...0002-of-00003.safetensors:  15%|██            |  732MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  16%|██▎           |  632MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  15%|██▏           | 2.10GB / 13.8GB,  100MB/s
# New Data Upload               :  75%|██████████▌   | 1.31GB / 1.74GB,  100MB/s
#
#   ...0002-of-00003.safetensors:  15%|██            |  738MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▎           |  636MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  15%|██▏           | 2.12GB / 13.8GB,  100MB/s
# New Data Upload               :  77%|██████████▋   | 1.34GB / 1.74GB,  100MB/s
#
#   ...0002-of-00003.safetensors:  15%|██            |  743MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▎           |  644MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  16%|██▏           | 2.14GB / 13.8GB,  101MB/s
# New Data Upload               :  78%|██████████▉   | 1.36GB / 1.74GB,  101MB/s
#
#   ...0002-of-00003.safetensors:  15%|██            |  749MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▎           |  645MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  16%|██▏           | 2.16GB / 13.8GB,  101MB/s
# New Data Upload               :  79%|███████████   | 1.38GB / 1.74GB,  101MB/s
#
#   ...0002-of-00003.safetensors:  15%|██▏           |  755MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▎           |  648MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  16%|██▏           | 2.18GB / 13.8GB,  101MB/s
# New Data Upload               :  80%|███████████▏  | 1.40GB / 1.74GB,  101MB/s
#
#   ...0002-of-00003.safetensors:  15%|██▏           |  761MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▍           |  653MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  16%|██▏           | 2.19GB / 13.8GB,  101MB/s
# New Data Upload               :  78%|██████████▉   | 1.41GB / 1.81GB,  101MB/s
#
#   ...0002-of-00003.safetensors:  16%|██▏           |  769MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▍           |  657MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  16%|██▏           | 2.21GB / 13.8GB,  100MB/s
# New Data Upload               :  79%|███████████   | 1.43GB / 1.81GB,  100MB/s
#
#   ...0002-of-00003.safetensors:  16%|██▏           |  774MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▍           |  661MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  16%|██▎           | 2.22GB / 13.8GB, 99.3MB/s
# New Data Upload               :  80%|███████████▏  | 1.44GB / 1.81GB, 99.3MB/s
#
#   ...0002-of-00003.safetensors:  16%|██▏           |  783MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▍           |  665MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  16%|██▎           | 2.24GB / 13.8GB, 99.0MB/s
# New Data Upload               :  81%|███████████▎  | 1.46GB / 1.81GB, 99.0MB/s
#
#   ...0002-of-00003.safetensors:  16%|██▏           |  793MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  17%|██▍           |  669MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  16%|██▎           | 2.26GB / 13.8GB, 99.1MB/s
# New Data Upload               :  82%|███████████▍  | 1.48GB / 1.81GB, 99.1MB/s
#
#   ...0002-of-00003.safetensors:  16%|██▎           |  801MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  18%|██▍           |  676MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  17%|██▎           | 2.28GB / 13.8GB, 98.9MB/s
# New Data Upload               :  83%|███████████▋  | 1.50GB / 1.81GB, 98.9MB/s
#
#   ...0002-of-00003.safetensors:  16%|██▎           |  805MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  18%|██▍           |  682MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  17%|██▎           | 2.30GB / 13.8GB, 98.4MB/s
# New Data Upload               :  84%|███████████▋  | 1.52GB / 1.81GB, 98.4MB/s
#
#   ...0002-of-00003.safetensors:  16%|██▎           |  811MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  18%|██▌           |  690MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  17%|██▎           | 2.32GB / 13.8GB, 98.3MB/s
# New Data Upload               :  82%|███████████▍  | 1.54GB / 1.88GB, 98.3MB/s
#
#   ...0002-of-00003.safetensors:  17%|██▎           |  817MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  18%|██▌           |  693MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  17%|██▎           | 2.34GB / 13.8GB, 98.1MB/s
# New Data Upload               :  80%|███████████▏  | 1.55GB / 1.94GB, 98.1MB/s
#
#   ...0002-of-00003.safetensors:  17%|██▎           |  823MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  18%|██▌           |  696MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  17%|██▍           | 2.35GB / 13.8GB, 97.4MB/s
# New Data Upload               :  78%|██████████▉   | 1.57GB / 2.01GB, 97.4MB/s
#
#   ...0002-of-00003.safetensors:  17%|██▎           |  835MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  19%|██▌           |  709MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  17%|██▍           | 2.37GB / 13.8GB, 98.5MB/s
# New Data Upload               :  79%|███████████   | 1.59GB / 2.01GB, 98.5MB/s
#
#   ...0002-of-00003.safetensors:  17%|██▍           |  841MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  19%|██▌           |  716MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  17%|██▍           | 2.39GB / 13.8GB, 98.9MB/s
# New Data Upload               :  80%|███████████▏  | 1.61GB / 2.01GB, 98.9MB/s
#
#   ...0002-of-00003.safetensors:  17%|██▍           |  849MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  19%|██▋           |  724MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  18%|██▍           | 2.41GB / 13.8GB, 98.5MB/s
# New Data Upload               :  78%|██████████▉   | 1.63GB / 2.08GB, 98.5MB/s
#
#   ...0002-of-00003.safetensors:  17%|██▍           |  858MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  19%|██▋           |  731MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  18%|██▍           | 2.43GB / 13.8GB, 98.5MB/s
# New Data Upload               :  79%|███████████   | 1.65GB / 2.08GB, 98.5MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▍           |  866MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  19%|██▋           |  737MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  18%|██▍           | 2.45GB / 13.8GB, 98.0MB/s
# New Data Upload               :  80%|███████████▏  | 1.67GB / 2.08GB, 98.0MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▍           |  873MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  19%|██▋           |  744MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  18%|██▌           | 2.46GB / 13.8GB, 98.0MB/s
# New Data Upload               :  81%|███████████▎  | 1.68GB / 2.08GB, 98.0MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▍           |  880MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  20%|██▋           |  751MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  18%|██▌           | 2.49GB / 13.8GB, 97.6MB/s
# New Data Upload               :  82%|███████████▍  | 1.71GB / 2.08GB, 97.6MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▌           |  889MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  20%|██▊           |  762MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  18%|██▌           | 2.51GB / 13.8GB, 97.7MB/s
# New Data Upload               :  81%|███████████▎  | 1.73GB / 2.15GB, 97.7MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▌           |  896MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  20%|██▊           |  768MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  18%|██▌           | 2.53GB / 13.8GB, 97.6MB/s
# New Data Upload               :  81%|███████████▍  | 1.75GB / 2.15GB, 97.6MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▌           |  902MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  20%|██▊           |  778MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▌           | 2.55GB / 13.8GB, 97.9MB/s
# New Data Upload               :  80%|███████████▏  | 1.77GB / 2.21GB, 97.9MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▌           |  904MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  20%|██▊           |  784MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▌           | 2.57GB / 13.8GB, 97.7MB/s
# New Data Upload               :  81%|███████████▎  | 1.78GB / 2.21GB, 97.7MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▌           |  908MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  792MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▋           | 2.59GB / 13.8GB, 97.5MB/s
# New Data Upload               :  82%|███████████▍  | 1.81GB / 2.21GB, 97.5MB/s
#
#   ...0002-of-00003.safetensors:  18%|██▌           |  911MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  794MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▋           | 2.60GB / 13.8GB, 96.6MB/s
# New Data Upload               :  82%|███████████▍  | 1.82GB / 2.21GB, 96.6MB/s
#
#   ...0002-of-00003.safetensors:  19%|██▌           |  918MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  797MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▋           | 2.61GB / 13.8GB, 95.3MB/s
# New Data Upload               :  83%|███████████▌  | 1.83GB / 2.21GB, 95.3MB/s
#
#   ...0002-of-00003.safetensors:  19%|██▌           |  924MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  800MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▋           | 2.63GB / 13.8GB, 95.4MB/s
# New Data Upload               :  84%|███████████▋  | 1.85GB / 2.21GB, 95.4MB/s
#
#   ...0002-of-00003.safetensors:  19%|██▋           |  930MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  802MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▋           | 2.65GB / 13.8GB, 95.2MB/s
# New Data Upload               :  82%|███████████▍  | 1.87GB / 2.28GB, 95.2MB/s
#
#   ...0002-of-00003.safetensors:  19%|██▋           |  939MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  804MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▋           | 2.67GB / 13.8GB, 95.1MB/s
# New Data Upload               :  83%|███████████▌  | 1.89GB / 2.28GB, 95.1MB/s
#
#   ...0002-of-00003.safetensors:  19%|██▋           |  946MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  806MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  19%|██▋           | 2.68GB / 13.8GB, 94.3MB/s
# New Data Upload               :  81%|███████████▎  | 1.90GB / 2.35GB, 94.3MB/s
#
#   ...0002-of-00003.safetensors:  19%|██▋           |  953MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  809MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  20%|██▋           | 2.70GB / 13.8GB, 94.0MB/s
# New Data Upload               :  82%|███████████▍  | 1.92GB / 2.35GB, 94.0MB/s
#
#   ...0002-of-00003.safetensors:  19%|██▋           |  963MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|██▉           |  817MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  20%|██▊           | 2.73GB / 13.8GB, 94.1MB/s
# New Data Upload               :  83%|███████████▌  | 1.94GB / 2.35GB, 94.1MB/s
#
#   ...0002-of-00003.safetensors:  20%|██▊           |  974MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  21%|███           |  823MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  20%|██▊           | 2.75GB / 13.8GB, 95.0MB/s
# New Data Upload               :  84%|███████████▋  | 1.97GB / 2.35GB, 95.0MB/s
#
#   ...0002-of-00003.safetensors:  20%|██▊           |  977MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  22%|███           |  829MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  20%|██▊           | 2.77GB / 13.8GB, 94.6MB/s
# New Data Upload               :  85%|███████████▊  | 1.98GB / 2.35GB, 94.6MB/s
#
#   ...0002-of-00003.safetensors:  20%|██▊           |  984MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  22%|███           |  837MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  20%|██▊           | 2.79GB / 13.8GB, 94.7MB/s
# New Data Upload               :  81%|███████████▎  | 2.00GB / 2.48GB, 94.7MB/s
#
#   ...0002-of-00003.safetensors:  20%|██▊           |  990MB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  22%|███           |  842MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  20%|██▊           | 2.80GB / 13.8GB, 94.8MB/s
# New Data Upload               :  82%|███████████▍  | 2.02GB / 2.48GB, 94.8MB/s
#
#   ...0002-of-00003.safetensors:  20%|██▊           | 1.00GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  22%|███           |  849MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  21%|██▊           | 2.82GB / 13.8GB, 95.4MB/s
# New Data Upload               :  82%|███████████▌  | 2.04GB / 2.48GB, 95.4MB/s
#
#   ...0002-of-00003.safetensors:  20%|██▊           | 1.01GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  22%|███▏          |  857MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  21%|██▉           | 2.85GB / 13.8GB, 95.7MB/s
# New Data Upload               :  83%|███████████▋  | 2.07GB / 2.48GB, 95.7MB/s
#
#   ...0002-of-00003.safetensors:  21%|██▊           | 1.01GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  23%|███▏          |  862MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  21%|██▉           | 2.86GB / 13.8GB, 95.4MB/s
# New Data Upload               :  84%|███████████▊  | 2.08GB / 2.48GB, 95.4MB/s
#
#   ...0002-of-00003.safetensors:  21%|██▉           | 1.02GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  23%|███▏          |  870MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  21%|██▉           | 2.89GB / 13.8GB, 95.5MB/s
# New Data Upload               :  83%|███████████▌  | 2.11GB / 2.55GB, 95.5MB/s
#
#   ...0002-of-00003.safetensors:  21%|██▉           | 1.03GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  23%|███▏          |  879MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  21%|██▉           | 2.91GB / 13.8GB, 96.1MB/s
# New Data Upload               :  83%|███████████▋  | 2.13GB / 2.55GB, 96.1MB/s
#
#   ...0002-of-00003.safetensors:  21%|██▉           | 1.03GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  23%|███▎          |  890MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  21%|██▉           | 2.93GB / 13.8GB, 96.0MB/s
# New Data Upload               :  84%|███████████▊  | 2.15GB / 2.55GB, 96.0MB/s
#
#   ...0002-of-00003.safetensors:  21%|██▉           | 1.04GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  23%|███▎          |  897MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  21%|██▉           | 2.95GB / 13.8GB, 96.1MB/s
# New Data Upload               :  85%|███████████▉  | 2.17GB / 2.55GB, 96.1MB/s
#
#   ...0002-of-00003.safetensors:  21%|██▉           | 1.04GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  24%|███▎          |  909MB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  22%|███           | 2.97GB / 13.8GB, 96.4MB/s
# New Data Upload               :  84%|███████████▋  | 2.19GB / 2.62GB, 96.4MB/s
#
#   ...0002-of-00003.safetensors:  21%|██▉           | 1.04GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  24%|███▎          |  920MB / 3.83GB
#
#
#
# ...
#
#
#
# Processing Files (0 / 3)      :  95%|█████████████▎| 13.1GB / 13.8GB,  115MB/s
# New Data Upload               :  98%|█████████████▋| 12.3GB / 12.6GB,  115MB/s
#
#   ...0002-of-00003.safetensors:  93%|████████████▉ | 4.59GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  95%|█████████████▎| 13.1GB / 13.8GB,  115MB/s
# New Data Upload               :  98%|█████████████▋| 12.4GB / 12.6GB,  115MB/s
#
#   ...0002-of-00003.safetensors:  93%|█████████████ | 4.60GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  95%|█████████████▎| 13.2GB / 13.8GB,  114MB/s
# New Data Upload               :  98%|█████████████▋| 12.4GB / 12.6GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  93%|█████████████ | 4.61GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  96%|█████████████▍| 13.2GB / 13.8GB,  113MB/s
# New Data Upload               :  97%|█████████████▌| 12.4GB / 12.7GB,  113MB/s
#
#   ...0002-of-00003.safetensors:  93%|█████████████ | 4.62GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  96%|█████████████▍| 13.2GB / 13.8GB,  113MB/s
# New Data Upload               :  97%|█████████████▋| 12.4GB / 12.7GB,  113MB/s
#
#   ...0002-of-00003.safetensors:  94%|█████████████ | 4.63GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  96%|█████████████▍| 13.2GB / 13.8GB,  113MB/s
# New Data Upload               :  98%|█████████████▋| 12.4GB / 12.7GB,  113MB/s
#
#   ...0002-of-00003.safetensors:  94%|█████████████▏| 4.64GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  96%|█████████████▍| 13.2GB / 13.8GB,  114MB/s
# New Data Upload               :  98%|█████████████▋| 12.4GB / 12.7GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  94%|█████████████▏| 4.65GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  96%|█████████████▍| 13.3GB / 13.8GB,  114MB/s
# New Data Upload               :  97%|█████████████▌| 12.5GB / 12.9GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  94%|█████████████▏| 4.66GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  96%|█████████████▍| 13.3GB / 13.8GB,  114MB/s
# New Data Upload               :  97%|█████████████▌| 12.5GB / 12.9GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  95%|█████████████▏| 4.68GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  96%|█████████████▌| 13.3GB / 13.8GB,  114MB/s
# New Data Upload               :  97%|█████████████▋| 12.5GB / 12.9GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  95%|█████████████▏| 4.68GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  97%|█████████████▌| 13.3GB / 13.8GB,  114MB/s
# New Data Upload               :  98%|█████████████▋| 12.5GB / 12.9GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  95%|█████████████▎| 4.69GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  97%|█████████████▌| 13.3GB / 13.8GB,  114MB/s
# New Data Upload               :  98%|█████████████▋| 12.6GB / 12.9GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  95%|█████████████▎| 4.70GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  97%|█████████████▌| 13.4GB / 13.8GB,  114MB/s
# New Data Upload               :  98%|█████████████▋| 12.6GB / 12.9GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  95%|█████████████▎| 4.71GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  97%|█████████████▌| 13.4GB / 13.8GB,  115MB/s
# New Data Upload               :  98%|█████████████▋| 12.6GB / 12.9GB,  115MB/s
#
#   ...0002-of-00003.safetensors:  95%|█████████████▎| 4.72GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  97%|█████████████▋| 13.4GB / 13.8GB,  115MB/s
# New Data Upload               :  98%|█████████████▋| 12.6GB / 12.9GB,  115MB/s
#
#   ...0002-of-00003.safetensors:  96%|█████████████▍| 4.74GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▊| 3.79GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  98%|█████████████▋| 13.4GB / 13.8GB,  116MB/s
# New Data Upload               :  98%|█████████████▋| 12.7GB / 12.9GB,  116MB/s
#
#   ...0002-of-00003.safetensors:  96%|█████████████▍| 4.75GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▉| 3.80GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  98%|█████████████▋| 13.5GB / 13.8GB,  116MB/s
# New Data Upload               :  98%|█████████████▋| 12.7GB / 12.9GB,  116MB/s
#
#   ...0002-of-00003.safetensors:  96%|█████████████▍| 4.76GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▉| 3.80GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  98%|█████████████▋| 13.5GB / 13.8GB,  117MB/s
# New Data Upload               :  98%|█████████████▋| 12.7GB / 13.0GB,  117MB/s
#
#   ...0002-of-00003.safetensors:  96%|█████████████▌| 4.77GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▉| 3.81GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  98%|█████████████▋| 13.5GB / 13.8GB,  116MB/s
# New Data Upload               :  98%|█████████████▋| 12.7GB / 13.0GB,  116MB/s
#
#   ...0002-of-00003.safetensors:  97%|█████████████▌| 4.78GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors:  99%|█████████████▉| 3.81GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  98%|█████████████▊| 13.5GB / 13.8GB,  116MB/s
# New Data Upload               :  98%|█████████████▊| 12.8GB / 13.0GB,  116MB/s
#
#   ...0002-of-00003.safetensors:  97%|█████████████▌| 4.79GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|█████████████▉| 3.81GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  98%|█████████████▊| 13.6GB / 13.8GB,  116MB/s
# New Data Upload               :  99%|█████████████▊| 12.8GB / 13.0GB,  116MB/s
#
#   ...0002-of-00003.safetensors:  97%|█████████████▌| 4.80GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|█████████████▉| 3.82GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  99%|█████████████▊| 13.6GB / 13.8GB,  115MB/s
# New Data Upload               :  99%|█████████████▊| 12.8GB / 13.0GB,  115MB/s
#
#   ...0002-of-00003.safetensors:  97%|█████████████▌| 4.81GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|█████████████▉| 3.82GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  99%|█████████████▊| 13.6GB / 13.8GB,  115MB/s
# New Data Upload               :  99%|█████████████▊| 12.8GB / 13.0GB,  115MB/s
#
#   ...0002-of-00003.safetensors:  97%|█████████████▋| 4.82GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|█████████████▉| 3.82GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  99%|█████████████▊| 13.6GB / 13.8GB,  114MB/s
# New Data Upload               :  99%|█████████████▊| 12.8GB / 13.0GB,  114MB/s
#
#   ...0002-of-00003.safetensors:  98%|█████████████▋| 4.83GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|█████████████▉| 3.83GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  99%|█████████████▊| 13.6GB / 13.8GB,  113MB/s
# New Data Upload               :  99%|█████████████▊| 12.8GB / 13.0GB,  113MB/s
#
#   ...0002-of-00003.safetensors:  98%|█████████████▋| 4.84GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|█████████████▉| 3.83GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  99%|█████████████▊| 13.6GB / 13.8GB,  112MB/s
# New Data Upload               :  99%|█████████████▊| 12.9GB / 13.0GB,  112MB/s
#
#   ...0002-of-00003.safetensors:  98%|█████████████▋| 4.85GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|█████████████▉| 3.83GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  99%|█████████████▉| 13.7GB / 13.8GB,  111MB/s
# New Data Upload               :  99%|█████████████▊| 12.9GB / 13.0GB,  111MB/s
#
#   ...0002-of-00003.safetensors:  98%|█████████████▊| 4.86GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|█████████████▉| 3.83GB / 3.83GB
#
#
#
# Processing Files (0 / 3)      :  99%|█████████████▉| 13.7GB / 13.8GB,  110MB/s
# New Data Upload               :  99%|█████████████▉| 12.9GB / 13.0GB,  110MB/s
#
#   ...0002-of-00003.safetensors:  99%|█████████████▊| 4.88GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (1 / 3)      :  99%|█████████████▉| 13.7GB / 13.8GB,  110MB/s
# New Data Upload               :  99%|█████████████▉| 12.9GB / 13.0GB,  110MB/s
#
#   ...0002-of-00003.safetensors:  99%|█████████████▊| 4.89GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (1 / 3)      :  99%|█████████████▉| 13.7GB / 13.8GB,  109MB/s
# New Data Upload               :  99%|█████████████▉| 12.9GB / 13.0GB,  109MB/s
#
#   ...0002-of-00003.safetensors:  99%|█████████████▊| 4.90GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (1 / 3)      : 100%|█████████████▉| 13.7GB / 13.8GB,  107MB/s
# New Data Upload               : 100%|█████████████▉| 12.9GB / 13.0GB,  107MB/s
#
#   ...0002-of-00003.safetensors:  99%|█████████████▉| 4.91GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (1 / 3)      : 100%|█████████████▉| 13.7GB / 13.8GB,  106MB/s
# New Data Upload               : 100%|█████████████▉| 12.9GB / 13.0GB,  106MB/s
#
#   ...0002-of-00003.safetensors:  99%|█████████████▉| 4.91GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (1 / 3)      : 100%|█████████████▉| 13.7GB / 13.8GB,  105MB/s
# New Data Upload               : 100%|█████████████▉| 13.0GB / 13.0GB,  105MB/s
#
#   ...0002-of-00003.safetensors:  99%|█████████████▉| 4.92GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (1 / 3)      : 100%|█████████████▉| 13.8GB / 13.8GB,  105MB/s
# New Data Upload               : 100%|█████████████▉| 13.0GB / 13.0GB,  105MB/s
#
#   ...0002-of-00003.safetensors: 100%|█████████████▉| 4.93GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (1 / 3)      : 100%|█████████████▉| 13.8GB / 13.8GB,  103MB/s
# New Data Upload               : 100%|█████████████▉| 13.0GB / 13.0GB,  103MB/s
#
#   ...0002-of-00003.safetensors: 100%|█████████████▉| 4.94GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (1 / 3)      : 100%|█████████████▉| 13.8GB / 13.8GB,  102MB/s
# New Data Upload               : 100%|█████████████▉| 13.0GB / 13.0GB,  102MB/s
#
#   ...0002-of-00003.safetensors: 100%|█████████████▉| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (2 / 3)      : 100%|█████████████▉| 13.8GB / 13.8GB,  101MB/s
# New Data Upload               : 100%|█████████████▉| 13.0GB / 13.0GB,  101MB/s
#
#   ...0002-of-00003.safetensors: 100%|█████████████▉| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (2 / 3)      : 100%|█████████████▉| 13.8GB / 13.8GB, 98.6MB/s
# New Data Upload               : 100%|█████████████▉| 13.0GB / 13.0GB, 98.6MB/s
#
#   ...0002-of-00003.safetensors: 100%|█████████████▉| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|█████████████▉| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|█████████████▉| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|█████████████▉| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (2 / 3)      : 100%|█████████████▉| 13.8GB / 13.8GB, 88.8MB/s
# New Data Upload               : 100%|█████████████▉| 13.0GB / 13.0GB, 88.8MB/s
#
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (3 / 3)      : 100%|██████████████| 13.8GB / 13.8GB, 86.0MB/s
# New Data Upload               : 100%|██████████████| 13.0GB / 13.0GB, 86.0MB/s
#
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
#
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#
#
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#
#
#
# Processing Files (3 / 3)      : 100%|██████████████| 13.8GB / 13.8GB, 70.4MB/s
# New Data Upload               : 100%|██████████████| 13.0GB / 13.0GB, 70.4MB/s
#   ...0002-of-00003.safetensors: 100%|██████████████| 4.95GB / 4.95GB
#   ...0003-of-00003.safetensors: 100%|██████████████| 3.83GB / 3.83GB
#   ...0001-of-00003.safetensors: 100%|██████████████| 5.00GB / 5.00GB
# README.md: 5.17kB [00:00, 887kB/s]
# Done! Full merged USPTO model pushed.
